# %% [markdown]
# ## Object oriented programming - A new programming paradigm
#
# Paradigm means the principle according to which a program is organized to carry out a given task.
#
# Python is an object-oriented programming (OOP) language. Unlike some other object-oriented languages, however, **Python doesn’t force you to use the object oriented paradigm exclusively: it also supports procedural programming, with modules and functions**, so that you can select the best paradigm for each part of your program. The object-oriented paradigm helps you group state (data) and behavior (functionality) together in handy packets of code.
#
# **a class is a user-defined type, which you instantiate to build instances, i.e., objects of that type.**

# %% [markdown]
# | Aspect                           | Object-Oriented Programming                                    | Functional Programming                                        |
# |---------------------------------|----------------------------------------------------------------|---------------------------------------------------------------|
# | **Primary Unit**                | Classes and objects encapsulating data and behavior            | Pure functions and immutable data                              |
# | **State Management**             | Supports mutable state within objects                           | Avoids mutable state; prefers immutability                     |
# | **Use Case**                    | Modeling complex, interacting systems with shared state        | Data transformations, parallelism, and pure calculations       |
# | **Code Modularity**             | High modularity via classes, inheritance, and polymorphism     | Modularity via function composition                            |
# | **Maintainability & Readability**| Better suited for large, evolving codebases with encapsulated behavior | Focused on small, stateless, and predictable functions         |
# | **Learning Curve**              | Easier to grasp real-world modeling for many developers        | Can be abstract and challenging due to recursion and higher-order functions |
# | **Performance**                | Efficient with stateful operations, but challenges in concurrency| Favorable for concurrency due to immutable data                |
# | **Error Handling**              | Mutable state can introduce bugs; requires careful design      | Functions produce less side effects, leading to fewer errors   |

# %% [markdown]
# ### What are Classes and Objects?

# %% [markdown]
# * World is object oriented. It is full of objects like Sparrow, Rose,
# Guitar, Keyboard, etc.
# * Each object is a specific instance of a class. For example, Sparrow is a
# specific instance of a Bird class or Rose is a specific instance of a
# Flower class.
# * More examples of classes and objects in real life:
# > * Bird is a class. Sparrow, Crow, Eagle are objects of Bird class.
# > * Player is a class. Sachin, Rahul, Kapil are objects of Player class.
# > * Flower is a class. Rose, Lily, Gerbera are objects of Flower class.
# > * Instrument is a class. Sitar, Flute are objects of Instrument class.

# %% [markdown]
# #### Terminology
#
# **Class: Classes are a collection of data and the actions that can modify the data.**
#
# * Classes were created to give users a mental model of how to think about data in a more concrete way.
# * Classes act as the blueprint - They tell Python what data is collected and how it can be modified.
#
# **Objects are constructed according to the blueprint that is the class.**
#
# **Instance - Another way that programmers talk about objects is to say that an object is an instance of a particular class.**
#
# **Instantiation is the process where an object is created according to blueprint of the class.**
#
# * With objects, you use the phrase "instantiate an object". That means to create an object, give it a name, store any data, and define the actions the object can perform.
#
# *A class is the blueprint used to create object. An object a version of a class used by programmers. An object is said to be an instance of a class.
# Instantiation is when an object is created from a class.*

# %% [markdown]
# **Class names - Start with an uppercase alphabet.**
#
# Example: Employee, Fruit, Bird, Complex, Tool, Machine

# %%
class Bird:
  pass

sparrow = Bird()
sparrow

# %%
isinstance(sparrow, Bird)
# Out:
# True

# %%
class Instrument:
  pass

guitar = Instrument()
guitar

# %%
isinstance(guitar, Instrument)
# Out:
# True

# %% [markdown]
# From the above examples we can infer that, a class describes two things
# 1. **the form an object created from it(class) will take** -  a Bird class may
# specify the form in terms of weight, color, number of feathers, etc.
# 2. **functionality it will have** - in terms of flying, hopping, chirping, eating, etc.
#
# In the programming jargon, **the form is often termed as properties** and **the functionality is often termed as methods**. A class lets us bundle data and functionality together.
#
# **Example**
# When objects like Sparrow or Eagle are created from the Bird class
# the properties will have values. The methods can either access or
# manipulate these values. The property weight will have
# value 250 grams for a Sparrow object, but 10 Kg for an Eagle object.

# %% [markdown]
# **Thus class is generic in nature, whereas an object is specific in
# nature.**

# %%
class Player:
  pass

sachin = Player()
sachin

# %%
isinstance(sachin, Player)
# Out:
# True

# %% [markdown]
# Multiple objects can be created from a class. The process of creation
# of an object from a class is called **instantiation**.

# %%
class Flower():
  pass

# %%
rose = Flower()
rose

# %%
isinstance(rose, Flower)
# Out:
# True

# %%
lily = Flower()
lily

# %%
isinstance(lily, Flower)
# Out:
# True

# %% [markdown]
# ### In Python every type is a class
#
# So int, float, complex, bool, str, list, tuple, set, dict are all classes.
#
# Almost all code in Python involves **creating and performing actions** on objects.
#
# A class has a name, whereas **objects are nameless**. Since objects do not have names, **they are referred using their addresses in memory**.
#
# **A class in Python is effectively a data type. All the data types built into Python are classes.**

# %% [markdown]
# An integer in Python is an object with both **state** (its numerical value) and **functionality** (operations it can perform).
#
# - It stores its value as its state.
# - It can perform arithmetic operations, such as addition. For example, `(10).__add__(100)` returns `110`, using the `__add__` method internally.
# - While `__add__` enables addition, typical syntax relies on `+` (e.g., `10 + 100`).
# - An integer object also knows how to represent itself as a string for display purposes.

# %%
num = 10 # num is an object of float class

# %%
print(type(num))
# Out:
# <class 'int'>

# %%
isinstance(num, int)
# Out:
# True

# %% [markdown]
# * When we use a simple statement `num = 10`, a nameless object of type `int` is created in memory and its address is stored in num. **Thus num refers to or points to the nameless object containing value 10.**
# * However, instead of saying that num refers to a nameless int object,
# often for sake of convenience, it is said that **num is an int object**.

# %%
num.as_integer_ratio()
# Out:
# (10, 1)

# %%
num.bit_count() #  Returns the number of ones in the binary representation of abs(i)
# Out:
# 2

# %%
num.bit_length() #  Returns the minimum number of bits needed to represent num
# Out:
# 4

# %%
# More programmatic examples of classes and objects
a = 3.14 # a is an object of float class

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
isinstance(a, float)
# Out:
# True

# %% [markdown]
# Floating-point numbers in Python are objects, just like integers.
#
# - **State**: A float's value represents its stored number.
# - **Functionality**: Floats support various operations, such as addition using `__add__`.
# - **Additional Methods**: Floats provide useful functions, like `.as_integer_ratio()`, which returns their exact fraction representation. For instance, `(0.125).as_integer_ratio()` outputs `(1, 8)`, meaning 0.125 is equivalent to **1/8**.
#
# This object-based approach allows Python to handle floats efficiently while providing built-in methods for precise calculations.

# %%
a.as_integer_ratio()
# Out:
# (7070651414971679, 2251799813685248)

# %%
s = 'Sudesh' # s is an object of str class

# %%
print(type(s))
# Out:
# <class 'str'>

# %%
isinstance(s, str)
# Out:
# True

# %%
lst = [10, 20, 30] # lst is an object of list class

# %%
print(type(lst))
# Out:
# <class 'list'>

# %%
isinstance(lst, list)
# Out:
# True

# %%
tpl = ('a', 'b', 'c') # tpl is an object of tuple class

# %%
print(type(tpl))
# Out:
# <class 'tuple'>

# %%
isinstance(tpl, tuple)
# Out:
# True

# %% [markdown]
# Different objects of a particular type may contain different data, but same methods. Consider the code snippet given below.

# %%
s1 = 'Rupesh' # s1 is object of type str
s2 = 'Geeta' # s2 is object of type str

# %% [markdown]
# Here s1 and s2 both are str objects containing different data/state like the characters, but same methods like upper( ), lower( ), capitalize( ), etc that operate on that state.
#
# The specific data in an object is often called instance data or properties of the object or state of the object or attributes of the object. Methods in an object are called instance methods.

# %%
print(dir(str))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %% [markdown]
# * `dir` is a built-in function that tells the user all of the attributes and methods associated with a class.
# * Because a string is a class, it is a powerful way of collecting and modifying data.

# %%
print(s1.__add__("!"))
# Out:
# Rupesh!

# %%
print(s1.__sizeof__())
# Out:
# 55

# %%
print(s1.startswith("R"))
# Out:
# True

# %%
def func():
  return None

# %%
isinstance(func, function)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-25-3744977197.py in <cell line: 0>()
# ----> 1 isinstance(func, function)
#
# NameError: name 'function' is not defined

# %%
import types
isinstance(func, types.FunctionType)
# Out:
# True

# %% [markdown]
# **What Is FunctionType?**
#
# * FunctionType is the **Python-internal type for all standard function objects created via def or lambda.**
#
# * It is available in the standard library under the **types** module as **types.FunctionType.**
#
# * The class alias is <class 'function'>, but this alias is not directly accessible as a global name; you use it via import types.

# %% [markdown]
# ### User-defined Classes
#
# In addition to providing ready-made classes like int, str, list, tuple, etc., Python permits us to define our own classes and create objects from them.
#
# The classes that we define are called user-defined data types. Rules for defining and using a user-defined class and a standard class are
# same.

# %%
class ClassName:
  pass

# %%
class ClassName:
  a = 10

# %% [markdown]
# The functions defined inside a class are known as **methods**.
#
# A class definition may optionally include a documentation string

# %%
# Let us define a user-defined class Employee.
class Employee:
  '''
  This is a sample class to show how a class looks like
  '''
  def set_data(self, n, a, s):
    self.name = n
    self.age = a
    self.salary = s
  def display_data(self) :
    print(self.name, self.age, self.salary)

# %%
Employee.__doc__
# Out:
# '\n  This is a sample class to show how a class looks like\n  '

# %% [markdown]
# Two nameless objects get created through the statements:
# ```
# e1 = Employee( )
# e2 = Employee( )
# ```
# Addresses of the nameless objects are stored in e1 and e2.
#
# In principle both the nameless objects should contain instance data name, age, salary and instance methods set_data( ) and display_data( ).
#
# The syntax to call an object's method is object.method( ), as in
# ```
# e1.set_data( )
# e1.display_data( )
# ```

# %%
e1 = Employee( )
# set_data( ) -
e1.set_data('Ramesh', 23, 25000)
e1.display_data( )
# Out:
# Ramesh 23 25000

# %%
e2 = Employee( )
e2.set_data('Suresh', 25, 30000)
e2.display_data( )
# Out:
# Suresh 25 30000

# %% [markdown]
# **Instance data is not shared since instance data values would be
# different from one object to another**

# %%
e1.__dict__
# Out:
# {'name': 'Ramesh', 'age': 23, 'salary': 25000}

# %%
e2.__dict__
# Out:
# {'name': 'Suresh', 'age': 25, 'salary': 30000}

# %% [markdown]
# #### Access Convention
#
# **How to access instance methods and instance data from outside the class?**

# %%
e3 = Employee( )
e3.name = 'Rakesh'
e3.age = 25

# %% [markdown]
# **How to make data in a class inaccessible from outside the class and access it only through member functions of the class?**
#
# There is no mechanism or keyword available in Python to enforce this. Hence a convention is used to start the instance data identifiers with two leading underscores (often called dunderscore, short for double underscore). Example: __name, __age and __salary.

# %%
class Employee:
  def __init__(self, n, a, s):
    self.__name = n
    self.__age = a
    self.__salary = s
  def display_data(self) :
    print(self.name, self.age, self.salary)

# %%
e4 = Employee('Rakesh', 25, 50000)

# %%
e4.__dict__
# Out:
# {'_Employee__name': 'Rakesh', '_Employee__age': 25, '_Employee__salary': 50000}

# %%
e4.__name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-bddb095e2aa0> in <cell line: 1>()
# ----> 1 e4.__name
#
# AttributeError: 'Employee' object has no attribute '__name'

# %% [markdown]
# #### Object Initialization with Constructor
#
# The constructor is a special method (more on methods in another lesson) for a class. Its job is to define all of attributes associated with the object. These attributes are called instance variables.
#
# In Python, the constructor is coded as __init__. The double underscores before and after init are required. The constructor also must have self as a parameter.
#
# Instead of using methods like  set_data( ), the benefit of initializing an object using the special method `__init__( )` is that it guarantees initialization, since `__init__( )` is always called when an object is created.
#
# If we do not define `__init__( )`, then Python inserts a default
# `__init__( )` method in our class.
#
# `__init__( )` is called only once during entire lifetime of an object.
#
# Attributes will be referred to as `self.attribute_name.`

# %%
# To compare set_data() and __init__() methods
class Employee :
  def set_data(self, n, a, s):
    self.__name = n
    self.__age = a
    self.__salary = s
  def display_data(self) :
    print(self.__name,self.__age, self.__salary)
  def __init__(self, n = ' ', a = 0,s = 0.0) :
    self.__name = n
    self.__age = a
    self.__salary = s

# %%
e1 = Employee( )

# %% [markdown]
# Whenever an object is created, space is allocated for it in memory
# and `__init__( )` is called. So address of object is passed to `__init__( )`.
#
# `__init__( )`'s parameters can take default values.

# %%
e1.__dict__
# Out:
# {'_Employee__name': ' ', '_Employee__age': 0, '_Employee__salary': 0.0}

# %%
e1.display_data( )
# Out:
#   0 0.0

# %% [markdown]
# A class may have __init__( ) as well as set_data( ).
# * `__init__( )` – To initialize object.
# * `set_data( )` – To modify an already initialized object.

# %%
e1.set_data('Suresh', 25, 30000)

# %%
e1.__dict__
# Out:
# {'_Employee__name': 'Suresh', '_Employee__age': 25, '_Employee__salary': 30000}

# %%
e1.display_data( )
# Out:
# Suresh 25 30000

# %%
e2 = Employee('Ramesh', 23, 25000)

# %%
e2.__dict__
# Out:
# {'_Employee__name': 'Ramesh', '_Employee__age': 23, '_Employee__salary': 25000}

# %%
e2.display_data( )
# Out:
# Ramesh 23 25000

# %% [markdown]
# When used with object, vars( ) returns a dictionary of the object's attributes and their values. In addition, it also returns the object's class's attributes, and recursively the attributes of its class's base classes.

# %%
vars(e1)
# Out:
# {'_Employee__name': 'Suresh', '_Employee__age': 25, '_Employee__salary': 30000}

# %%
vars(e2)
# Out:
# {'_Employee__name': 'Ramesh', '_Employee__age': 23, '_Employee__salary': 25000}

# %% [markdown]
# When used with class, vars( ) returns a dictionary of the class's attributes and their values.

# %%
vars(Employee)
# Out:
# mappingproxy({'__module__': '__main__',
#               'set_data': <function __main__.Employee.set_data(self, n, a, s)>,
#               'display_data': <function __main__.Employee.display_data(self)>,
#               '__init__': <function __main__.Employee.__init__(self, n=' ', a=0, s=0.0)>,
#               '__dict__': <attribute '__dict__' of 'Employee' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Employee' objects>,
#               '__doc__': None})

# %%
# To compare set_data() and __init__() methods
class Employee :
  def set_data(self, n, a, s) :
    self.__name = n
    self.__age = a
    self.__salary = s
  def display_data(self) :
    print(self.__name,self.__age, self.__salary)
  def __init__(self, n = ' ', a = 0,s = 0.0) :
    self.__name = n
    self.__age = a
    self.__salary = s
  def __del__(self):
    print('Deleting object' + str(self))

# %%
e3 = Employee('Naresh', 21, 20000)

# %%
vars(e3)
# Out:
# {'_Employee__name': 'Naresh', '_Employee__age': 21, '_Employee__salary': 20000}

# %%
e3.display_data()
# Out:
# Naresh 21 20000

# %% [markdown]
# `__del__( )` method gets called automatically when an object goes
# out of scope. Cleanup activity, if any, should be done in `__del__( )`.

# %%
e3 = None
# Out:
# Deleting object<__main__.Employee object at 0x7c93818e1b10>

# %% [markdown]
# **self** -  Whenever we call an instance method using an object, **address of
# the object gets passed to the method implicitly**. This **address is
# collected by the instance method in a variable** called self.
#
# Using address of the object present in self we indicate which object's instance data we wish to work with. To do this we prepend the instance data with self., as in self.name,self.age and self.salary.

# %%
class Employee :
  def __init__(self, n = ' ', a = 0,s = 0.0) :
    self.__name = n
    self.__age = a
    self.__salary = s
    print('The address of self is: ', hex(id(self)))
  def display_data(self) :
    print(self.__name,self.__age, self.__salary)
  def __del__(self) :
    print('Deleting object' + str(self))

# %%
e1 = Employee()
e1
# Out:
# The address of self is:  0x7a175720beb0

# %%
e2 = Employee()
e2
# Out:
# The address of self is:  0x7a175720a920

# %%
e3 = Employee()
e3
# Out:
# The address of self is:  0x7a17572097b0

# %% [markdown]
# ### Class Variable/attribute and Methods
#
# * If we wish to share a variable amongst all objects of a class, we must
# declare the variable as a class variable or class attribute.
# * To declare a class variable, we have to create a variable without
# prepending it with self.
# * The __init__ method creates object attributes. These can be different from object to object.
# * However, a class attribute is the same for every object. The class attribute is defined after the docstring and before the `__init__` method. **Class variables do not become part of objects of a class.**
#
# *A class attribute is an attribute shared by all instances of a class. An object attribute is an attribute created by the `__init__` method.*

# %%
class Employee:
  org_name = 'ABC' # class variable or class attribute
  def set_data(self, n, a, s):
    self.__name = n
    self.__age = a
    self.__salary = s
  def display_data(self):
    print(self.__name,self.__age, self.__salary)
  def __init__(self, n = ' ', a = 0,s = 0.0) :
    self.__name = n
    self.__age = a
    self.__salary = s
    self.address = id(self)
  def __del__(self):
    print('Deleting object' + str(self))

# %%
e1 = Employee( )
e1.set_data('Suresh', 25, 30000)
e1.display_data( )
e2 = Employee('Ramesh', 23, 25000)
e2.display_data( )
e1 = None
e2 = None
# Out:
# Suresh 25 30000
# Ramesh 23 25000
# Deleting object<__main__.Employee object at 0x7b0d13a68310>
# Deleting object<__main__.Employee object at 0x7b0d13a68210>

# %% [markdown]
# Class variables are accessed using the syntax **classname.varname**.

# %%
Employee.org_name
# Out:
# 'ABC'

# %%
e = Employee()
e
# Out:
# Deleting object<__main__.Employee object at 0x7c93816bb490>

# %%
e.org_name
# Out:
# 'ABC'

# %% [markdown]
# * Contrasted with instance methods, class methods do not receive a self argument.
# * Class methods can be accessed using the syntax **classname.methodname( )**.

# %%
class Employee :
  org_name = 'ABC' # class variable or class attribute
  def set_data(self, n, a, s) :
    self.__name = n
    self.__age = a
    self.__salary = s
  def display_data(self) :
    print(self.__name,self.__age, self.__salary)
  def __init__(self, n = ' ', a = 0,s = 0.0) :
    self.__name = n
    self.__age = a
    self.__salary = s
  def class_method():
    print('This is a class method')
  def __del__(self) :
    print('Deleting object' + str(self))

# %%
emp = Employee()
emp

# %%
emp.class_method()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-3f0531418520> in <cell line: 1>()
# ----> 1 emp.class_method()
#
# TypeError: Employee.class_method() takes 0 positional arguments but 1 was given

# %%
Employee.class_method()
# Out:
# This is a class method

# %%
class Employee :
  org_name = 'ABC' # class variable or class attribute
  def set_data(self, n, a, s) :
    self.__name = n
    self.__age = a
    self.__salary = s
  def display_data(self) :
    print(self.__name,self.__age, self.__salary)
  def __init__(self, n = ' ', a = 0,s = 0.0) :
    self.__name = n
    self.__age = a
    self.__salary = s
  def class_method(cls):
    print('This is a class method')
  def __del__(self) :
    print('Deleting object' + str(self))

# %%
empl = Employee()
empl

# %%
empl.class_method()
# Out:
# This is a class method

# %%
Employee.class_method()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-1e539a16f905> in <cell line: 1>()
# ----> 1 Employee.class_method()
#
# TypeError: Employee.class_method() missing 1 required positional argument: 'cls'

# %%
Employee.class_method(empl)
# Out:
# This is a class method

# %%
Employee.class_method(self)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-bfdc8983afff> in <cell line: 1>()
# ----> 1 Employee.class_method(self)
#
# NameError: name 'self' is not defined

# %% [markdown]
# **Class variables can be used to count how many objects have been
# created from a class.**

# %%
class Fruit :
  count = 0
  def __init__(self, name = ' ', size = 0, color = ' ') :
    self.__name = name
    self.__size = size
    self.__color = color
    Fruit.count += 1
  def display( ) :
    print(Fruit.count)

# %%
f1 = Fruit('Banana', 5, 'Yellow')
f2 = Fruit('Orange', 4, 'Orange')
f3 = Fruit('Apple', 3, 'Red')

# %%
Fruit.display()
# Out:
# 3

# %%
print(Fruit.count)
# Out:
# 3

# %% [markdown]
# **Check what happens if we define count as a instance variable**

# %%
class Fruit :
  count = 0
  def __init__(self, name = ' ', size = 0, color = ' ') :
    self.__name = name
    self.__size = size
    self.__color = color
    self.count += 1
  def display( ) :
    print(Fruit.count)

# %%
f1 = Fruit('Banana', 5, 'Yellow')
f2 = Fruit('Orange', 4, 'Orange')
f3 = Fruit('Apple', 3, 'Red')

# %%
f1.count, f2.count, f3.count
# Out:
# (1, 1, 1)

# %%
Fruit.display()
# Out:
# 0

# %%
print(Fruit.count)
# Out:
# 0

# %% [markdown]
# ### Shallow & Deep Copies
# * The code below will instantiate `a` as an instance of the ComicBookCharacter class.
# * Object a will be given a name, an age, and a type. Object `b` will be a copy of `a`. Finally, the name attribute of object a is changed.
#
# **What do you expect to see when the name attributes of objects a and b are printed?**

# %%
class ComicBookCharacter():
  pass

a = ComicBookCharacter()
a.name = "Calvin"
a.age = 6
a.type = "human"

b = a
a.name = "Hobbes"

print(a.name)
print(b.name)
# Out:
# Hobbes
# Hobbes

# %% [markdown]
# * Both of the name attributes changed, even though the code only changed the name attribute of object `a`. This is because object `b` is a shallow copy of object `a`.
# * Python makes a copy of object `a`, but object `b` shares the attributes with object `a`. That is why changing name for object a also affects the name attribute for object b.

# %%
import copy
class ComicBookCharacter():
  pass

a = ComicBookCharacter()
a.name = "Calvin"
a.age = 6
a.type = "human"

b = copy.copy(a)
a.name = "Hobbes"

print(a.name)
print(b.name)
# Out:
# Hobbes
# Calvin

# %% [markdown]
# #### Deepcopy
#
# * A deep copy is when Python makes a copy of object `a` and makes copies of each attribute.
# * A deep copy keeps the attributes of one object independent of the other object. To create a deep copy, you need to import the copy module.

# %%
import copy

class ComicBookCharacter():
  pass

a = ComicBookCharacter()
a.name = "Calvin"
a.age = 6
a.type = "human"

b = copy.deepcopy(a)
a.name = "Hobbes"

print(a.name)
print(b.name)
# Out:
# Hobbes
# Calvin

# %% [markdown]
# **Summary: A deep copy is when Python makes a copy of the object and its attributes. A shallow copy is when Python makes a copy of the object, but the attributes are shared.**
# * Python requires the copy module to make a deep copy.
# * Shallow copies only make a copy of the object, but not of the attributes.
# * Deep copes make a copy of the object and the attributes.
# * Changing an attribute of one shallow copy will affect the attribute of the other shallow copy.

# %% [markdown]
# ### Mutability
# **Objects are mutable, which means that objects (specifically their attributes) can change value.**
#
# **Example - Think of a video game**
# * the main character in the game is constantly changing. It could be their position on the screen, the score, their health, the items in their inventory, etc.
# * Imagine a simple class called Player. A newly instantiated Player object has a health of 100, a score of 0, and starts on level 1. This object can lose health, increase their score, and advance levels.

# %%
class Player:
  """Simple player class"""
  def __init__(self, health=100, score=0, level=1):
    self.health = health
    self.score = score
    self.level = level

player1 = Player()
print(f"This player has {player1.health} health, a score of {player1.score}, and is on level {player1.level}.")
player1.health -= 10
player1.score += 25
player1.level += 1
print(f"This player has {player1.health} health, a score of {player1.score}, and is on level {player1.level}.")
# Out:
# This player has 100 health, a score of 0, and is on level 1.
# This player has 90 health, a score of 25, and is on level 2.

# %% [markdown]
# **One of the benefits of functions is code reusability. The example above has a repetition of the print statement. This is a good opportunity to use a function.**

# %%
class Player:
  """Simple player class"""
  def __init__(self, health=100, score=0, level=1):
    self.health = health
    self.score = score
    self.level = level

def print_player(p):
  """Print the status of a player"""
  print(f"This player has {p.health} health, a score of {p.score}, and is on level {p.level}.")

player1 = Player()
print_player(player1)
player1.health -= 10
player1.score += 25
player1.level += 1
print_player(player1)
# Out:
# This player has 100 health, a score of 0, and is on level 1.
# This player has 90 health, a score of 25, and is on level 2.

# %% [markdown]
# Using a function to print the status of  player1 may not seem like it was worth the effort to change the code. But when these functions become more complex, The efficiency becomes clear.

# %%
class Player:
  """Simple player class"""
  def __init__(self, health=100, score=0, level=1):
    self.health = health
    self.score = score
    self.level = level

def print_player(p):
  """Print the status of a player"""
  if p.health <= 0:
    print(f"This player is dead. They died on level {p.level} with a score of {p.score}.")
  else:
    print(f"This player has {p.health} health, a score of {p.score}, and is on level {p.level}.")

player1 = Player()
print_player(player1)
player1.health = 0
player1.score += 25
player1.level += 1
print_player(player1)
# Out:
# This player has 100 health, a score of 0, and is on level 1.
# This player is dead. They died on level 2 with a score of 25.

# %% [markdown]
# **Create a function to change a player’s health and player's level?**

# %%
class Player:
  """Simple player class"""
  def __init__(self, health=100, score=0, level=1):
    self.health = health
    self.score = score
    self.level = level


def print_player(p):
  """Print the status of a player"""
  if p.health <= 0:
    print(f"This player is dead. They died on level {p.level} with a score of {p.score}.")
  else:
    print(f"This player has {p.health} health, a score of {p.score}, and is on level {p.level}.")

def change_health(p, amount):
  """Change a player's health"""
  p.health += amount

def change_level(p):
  """Change a player's level"""
  p.level += 1

player1 = Player()
print_player(player1)
player1.score += 25
change_health(player1, -25)
change_level(player1)
print_player(player1)
# Out:
# This player has 100 health, a score of 0, and is on level 1.
# This player has 75 health, a score of 25, and is on level 2.

# %% [markdown]
# **Object mutability is the concept that object attributes can be changed.**

# %% [markdown]
# ### Methods vs Functions
# * A class was defined as “a collection of data and the actions (functionalities) that can modify the data.”
# * The constructor built the "collection of data", but nothing in the class modified the data. Instead, external functions were used to modify the object.

# %%
class Player:
  """Simple player class"""
  def __init__(self, health=100, score=0, level=1):
    self.health = health
    self.score = score
    self.level = level

def change_level(p):
  '''
  Changes player level
  '''
  p.level += 1

# %%
mario = Player()
print('Player in level', mario.level)
change_level(mario)
print('Player in level', mario.level)
# Out:
# Player in level 1
# Player in level 2

# %% [markdown]
# * Instead of functions, methods should be used to modify an object. Think of a method as an function that is attached to an object. The instance method is the most common type of method.

# %% [markdown]
# ### Instance Method
# **How instance methods are declared inside of the class?**
# * The keyword self is used to represent the instance being modified by the method. These methods are called instance methods because they have access to the instance variables (the attributes declared in the constructor).
# * Methods are invoked using dot-notation.
# * Instance methods are the most common type of methods in Python. They are so common that when programmers say "method" they often mean an instance method.

# %%
class Player:
  """Simple player class"""
  def __init__(self, health=100, score=0, level=1):
    self.health = health
    self.score = score
    self.level = level

  def print_player(self):
    """Print the status of a player"""
    if self.health <= 0:
      print(f"This player is dead. They died on level {self.level} with a score of {self.score}.")
    else:
      print(f"This player has {self.health} health, a score of {self.score}, and is on level {self.level}.")

# %%
mario = Player()
mario.print_player()
# Out:
# This player has 100 health, a score of 0, and is on level 1.

# %% [markdown]
# **What does self mean?**
# * `self` is required as the first parameter for instance methods. It gives the method access to the instance variables.
# * Without self, print_player would not be able to "see" the health, score, and level instance variables for mario.
# * Remove self from the print_player definition, and Python will return an error message.

# %%
class Player:
  """Simple player class"""
  def __init__(self, health=100, score=0, level=1):
    self.health = health
    self.score = score
    self.level = level

  def print_player():
    """Print the status of a player"""
    if health <= 0:
      print(f"This player is dead. They died on level {level} with a score of {score}.")
    else:
      print(f"This player has {health} health, a score of {score}, and is on level {level}.")

# %%
mario = Player()
print_player(mario)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-15f28aa8b0f4> in <cell line: 2>()
#       1 mario = Player()
# ----> 2 print_player(mario)
#
# NameError: name 'print_player' is not defined

# %% [markdown]
# * Python says that print_player is not defined even though the definition is available.
# * Because nothing comes before print_player, Python assumes that this is a function.
# * However, print_player is indented inside the Player class, which means it is a method.

# %% [markdown]
# * The next methods to add to the Player class are those to print the health and level of the Player instance.
# * Start with the method change_health. This method takes self and the amount of change as parameters. change_health will add amount to the health attribute.
# * If a player’s health increases, amount is positive. If their health decreases, amount is negative.

# %%
class Player:
  """Simple player class"""
  def __init__(self, health=100, score=0, level=1):
    self.health = health
    self.score = score
    self.level = level

  def change_health(self, amount):
    """Change a player's health"""
    self.health += amount

  def print_player(self):
    """Print the status of a player"""
    if self.health <= 0:
      print(f"This player is dead. They died on level {self.level} with a score of {self.score}.")
    else:
      print(f"This player has {self.health} health, a score of {self.score}, and is on level {self.level}.")

# %%
mario = Player()
mario.change_health(-30)
mario.print_player()
# Out:
# This player has 70 health, a score of 0, and is on level 1.

# %% [markdown]
# * The method change_level is going to be similar to change_health except for one difference. change_level only needs one parameter, self.
# * In video games, players go up in levels; rarely do they decrease. So the level attribute will increase by one when the method is called.

# %%
class Player:
  """Simple player class"""
  def __init__(self, health=100, score=0, level=1):
    self.health = health
    self.score = score
    self.level = level

  def change_health(self, amount):
    """Change a player's health"""
    self.health += amount

  def change_level(self):
    """Change a player's level"""
    self.level += 1

  def print_player(self):
    """Print the status of a player"""
    if self.health <= 0:
      print(f"This player is dead. They died on level {self.level} with a score of {self.score}.")
    else:
      print(f"This player has {self.health} health, a score of {self.score}, and is on level {self.level}.")

# %%
mario = Player()
mario.print_player()
mario.change_health(-30)
mario.change_level()
mario.print_player()
# Out:
# This player has 100 health, a score of 0, and is on level 1.
# This player has 70 health, a score of 0, and is on level 2.

# %% [markdown]
# **Create a method to change a player’s score?**

# %%
class Player:
  """Simple player class"""
  def __init__(self, health=100, score=0, level=1):
    self.health = health
    self.score = score
    self.level = level

  def change_health(self, amount):
    """Change a player's health"""
    self.health += amount

  def change_level(self):
    """Change a player's level"""
    self.level += 1

  def change_score(self, amount):
    """Change a player's score"""
    self.score += amount

  def print_player(self):
    """Print the status of a player"""
    if self.health <= 0:
      print(f"This player is dead. They died on level {self.level} with a score of {self.score}.")
    else:
      print(f"This player has {self.health} health, a score of {self.score}, and is on level {self.level}.")

# %%
mario = Player()
mario.print_player()
mario.change_health(-30)
mario.change_level()
mario.change_score(500)
mario.print_player()
# Out:
# This player has 100 health, a score of 0, and is on level 1.
# This player has 70 health, a score of 500, and is on level 2.

# %% [markdown]
# #### Methods and Objects
# * Changes to objects should happen exclusively through methods. This makes your code easier to organize and easier for others to understand.
#
# **Example:**
# * Imagine you are going to create a class that keeps track of a meal. In this case, a meal can be thought of as all of the drinks, appetizers, courses, and desserts served.
# * Each one of these categories will become an instance variable. Assign each attribute an empty list with the constructor, and create an instance of the Meal class.

# %%
class Meal:
  """Class to represent a meal"""
  def __init__(self):
    self.drinks = []
    self.appetizers = []
    self.main_course = []
    self.desserts = []

# %%
dinner = Meal()
dinner

# %% [markdown]
# **Add a method to add a drink to dinner**
# * `self.drinks` is used to access the list of drinks, and `.append` is the command to add an element to the list.
# * So `self.drinks.append(d)` adds the drink d to the list drinks.

# %%
class Meal:
  """Class to represent a meal"""
  def __init__(self):
    self.drinks = []
    self.appetizers = []
    self.main_course = []
    self.desserts = []

  def add_drink(self, d):
    """Add a drink (d) to the meal (self)"""
    self.drinks.append(d)

# %%
dinner = Meal()
dinner.add_drink("water")
print(dinner.drinks)
# Out:
# ['water']

# %% [markdown]
# **Create the add_appetizer method to the class**
# * Like the method above, add_appetizer accepts a string as a parameter and appends it to the appetizers attribute.
# * Add "bruschetta" to the dinner instance and print it.

# %%
class Meal:
  """Class to represent a meal"""
  def __init__(self):
    self.drinks = []
    self.appetizers = []
    self.main_course = []
    self.desserts = []

  def add_drink(self, d):
    """Add a drink (d) to the meal (self)"""
    self.drinks.append(d)

  def add_appetizer(self, a):
    """Add an appetizer (a) to the meal (self)"""
    self.appetizers.append(a)

# %%
dinner = Meal()
dinner.add_drink("water")
print(dinner.drinks)
dinner.add_appetizer("bruschetta")
print(dinner.appetizers)
# Out:
# ['water']
# ['bruschetta']

# %% [markdown]
# * `add_course` - accepts a string which represents a course and adds it to the meal.
# * `add_dessert` - accepts a string which represents a dessert and adds it to the meal.
# * Test your code using "roast chicken" as a main course and "chocolate cake" as a dessert.

# %%
class Meal:
  """
  Class to represent a meal
  """
  def __init__(self):
    self.drinks = []
    self.appetizer = []
    self.courses = []
    self.dessert = []

  def add_drink(m, d):
    """Add a drink (d) to the meal (m)"""
    m.drinks.append(d)

  def add_appetizer(m, a):
    """Add an appetizer (a) to the meal (m)"""
    m.appetizer.append(a)

  def add_course(m, c):
    """Add a course (c) to the meal (m)"""
    m.courses.append(c)

  def add_dessert(m, d):
    """Add a dessert (d) to the meal (m)"""
    m.dessert.append(d)

# %%
dinner = Meal()
dinner.add_drink("water")
dinner.add_appetizer("bruschetta")
dinner.add_course("roast chicken")
dinner.add_dessert("chocolate cake")

print(dinner.drinks)
print(dinner.appetizer)
print(dinner.courses)
print(dinner.dessert)
# Out:
# ['water']
# ['bruschetta']
# ['roast chicken']
# ['chocolate cake']

# %% [markdown]
# ### Class Method
# * A class method is a method that has access to the class, but not the object instance. That means a class method does not have access to the instance variables (the attributes in the constructor).
# * It does have access to the class itself. If the class has class attributes, then a class method can access them.
#
# **When defining class methods in Python, the decorator @classmethod is used. Class methods also take cls as a parameter. Below is an example of a class method:**

# %%
@classmethod
def my_class_method(cls):
  print("I am a class method")

# %% [markdown]
# **Example:**
# The National Football League (NFL) has a salary cap. That means every team must spend below a certain amount of money. The class below defines an NFL team. Since the same salary cap applies to all teams, it is stored as a class attribute.

# %%
class NFLteam:
    """Define the NFL team class"""
    salary_cap = 198200000
    def __init__(self, city, name):
        self.city = city
        self.name = name

# %% [markdown]
# * Each year, the salary cap is adjusted based on the league’s revenues. So there needs to be a way in which to change the salary_cap attribute. This attribute is a class attribute, not an instance attribute.
# * A class method is best suited for this job. **Class methods are differentiated from instance methods by the @classmethod decorator**. The decorator informs Python that the method is a class method and not an instance method. In addition, class methods also take cls as the parameter.

# %% [markdown]
# #### `self` versus `cls`
# * An instance method needs access to the instance variables. `self` refers to the instantiated object of the class, which is what gives the method access to the instance variables.
# * A class method needs access to the class variables. `cls` refers to the class as a whole, which is what gives the method access to the class variables.

# %%
class NFLteam:
    """Define the NFL team class"""
    salary_cap = 198200000
    def __init__(self, city, name):
        self.city = city
        self.name = name

    @classmethod
    def change_salary_cap(cls, new_cap):
        cls.salary_cap = new_cap

# %%
team_1 = NFLteam("Cincinnati", "Bengals")
team_2 = NFLteam("New England", "Patriots")
NFLteam.change_salary_cap(199000000)

print(team_1.salary_cap)
print(team_2.salary_cap)
# Out:
# 199000000
# 199000000

# %% [markdown]
# * Originally the salary cap was 198200000. Then the class method change_salary_cap changed it to 199000000.
# * Since team_1 and team_2 are instances of the NFLteam class, their class attribute salary_cap was affected.

# %%
class NFLteam:
    """Define the NFL team class"""
    salary_cap = 198200000
    def __init__(self, city, name):
        self.city = city
        self.name = name

    @classmethod
    def change_salary_cap(cls, new_cap):
        cls.salary_cap = new_cap

# %%
team_1 = NFLteam("Cincinnati", "Bengals")
team_2 = NFLteam("New England", "Patriots")
team_1.change_salary_cap(199000000)

print(team_1.salary_cap)
print(team_2.salary_cap)
# Out:
# 199000000
# 199000000

# %% [markdown]
# **Why was team_2 affected when the method was called on team_1?**
# * If change_salary_cap was called on team_1, it seems reasonable that the change in salary_cap would only affect team_1.
# * However, salary_cap is a class attribute, and change_salary_cap is a class method. That means all instances of the NFLteam class will be affected.

# %% [markdown]
# #### Class Methods Cannot Affect Instance Variables
# * It makes sense that a class method cannot change an instance variable. Class methods take `cls` as a parameter and not `self`.
# * The change_city method is a class method (as shown by its decorator), but it takes self as a parameter. The method also changes the instance variable city from "Dallas" to "Portland".

# %%
class NFLteam:
    """Define the NFL team class"""
    salary_cap = 198200000
    def __init__(self, city, name):
        self.city = city
        self.name = name

    @classmethod
    def change_city(self, new_city):
        self.city = new_city

# %%
team = NFLteam("Dallas", "Cowboys")
team.change_city("Portland")
print(team.city)
# Out:
# Dallas

# %% [markdown]
# * **The instance variable was not changed**. The @classmethod decorator keeps change_city from altering the instance variables **even if `self` is passed to the method**.

# %% [markdown]
# **What happened to the string "Portland"?**
# * If the instance variable was not changed and there was no error message, what happened?

# %%
class NFLteam:
    """Define the NFL team class"""
    salary_cap = 198200000
    def __init__(self, city, name):
        self.city = city
        self.name = name

    @classmethod
    def change_city(self, new_city):
        self.city = new_city

# %%
team = NFLteam("Dallas", "Cowboys")
team.change_city("Portland")
print(team.city)
print(NFLteam.city)
# Out:
# Dallas
# Portland

# %% [markdown]
# #### Factory Methods
# **Alternate Constructor**
# * A common use for class methods is to create an “alternative” constructor. Imagine that you have a Pizza class, whose constructor takes a list of toppings (sauce, cheese, vegetables, meats, herbs, etc.).
# * Using the standard constructor, create a Margherita pizza (sauce, mozzarella, and basil).

# %%
class Pizza:
  """Pizza class with a list of toppings"""
  def __init__(self, toppings):
    self.toppings= toppings

# %%
my_pizza = Pizza(["tomato sauce", "mozzarella", "basil"])
print(my_pizza.toppings)
# Out:
# ['tomato sauce', 'mozzarella', 'basil']

# %% [markdown]
# * Margherita pizza is very popular, and the toppings are very specific. It would be nice to tell Python to make a Margherita pizza instead of having to list out all of the toppings each time.
# * That is where class methods help out. You can write a class method that calls the constructor with predetermined set of parameters.
# * This type of class method is referred to as a **factory method**.

# %%
class Pizza:
  """Pizza class with a list of toppings"""
  def __init__(self, toppings):
    self.toppings= toppings

  @classmethod
  def make_margherita(cls):
    return Pizza(["tomato sauce", "mozzarella", "basil"])

# %%
my_pizza = Pizza.make_margherita()
print(my_pizza.toppings)
# Out:
# ['tomato sauce', 'mozzarella', 'basil']

# %% [markdown]
# **Do not forget `return` in the class method**
#
# * It is important to use the return statement when using class methods as an alternative constructor.
# * If not, my_pizza will have the value of None and my_pizza.toppings will be undefined.
# * Variables can have a value of None, but an undefined attribute will cause an error.

# %% [markdown]
# **Create a class method that creates a veggie pizza, with toppings("tomato sauce", "mozzarella", "mushroom", "bell pepper").**

# %%
class Pizza:
  """Pizza class with a list of toppings"""
  def __init__(self, toppings):
    self.toppings= toppings

  @classmethod
  def make_veggie(cls):
    return Pizza(["tomato sauce", "mozzarella", "mushroom", "bell pepper"])

# %%
my_pizza = Pizza.make_veggie()
print(my_pizza.toppings)
# Out:
# ['tomato sauce', 'mozzarella', 'mushroom', 'bell pepper']

# %% [markdown]
# **Create a class method that creates a three-cheese pizza, with toppings ("tomato sauce", "mozzarella", "fontina", "parmesan").**

# %%
class Pizza:
  """Pizza class with a list of toppings"""
  def __init__(self, toppings):
    self.toppings= toppings

  @classmethod
  def make_three_cheese(cls):
    return Pizza(["tomato sauce", "mozzarella", "fontina", "parmesan"])

# %%
my_pizza = Pizza.make_three_cheese()
print(my_pizza.toppings)
# Out:
# ['tomato sauce', 'mozzarella', 'fontina', 'parmesan']

# %% [markdown]
# ### Static Methods
# The third type of method in Python is a static method. Static methods are most often used to add functionality (like calculating the combined area) to a class. These methods use the @staticmethod decorator, and they do not require a special parameter like self or cls.

# %% [markdown]
# **Example:**
# * Imagine a Rectangle class in which objects have a length, width, and a method to calculate the area.
# * Create two instances of the Rectangle class, and then calculate the combined area of the two rectangles.

# %%
class Rectangle:
  """Rectangle class"""
  def __init__(self, l, w):
    self.length = l
    self.width= w

  def area(self):
    """Calculate the area of the rectangle"""
    return self.length * self.width

# %%
rect_1 = Rectangle(12, 27)
rect_2 = Rectangle(9, 3)
combined_area = rect_1.area() + rect_2.area()
print(combined_area)
# Out:
# 351

# %% [markdown]
# This works, but the combined area has to be calculated by the user. Since the combined area is related to the Rectangle class, a better solution would be to add this functionality to the class.

# %%
class Rectangle:
  """Rectangle class"""
  def __init__(self, l, w):
    self.length = l
    self.width= w

  def area(self):
    """Calculate the area of the rectangle"""
    return self.length * self.width

  @staticmethod
  def combined_area(r1, r2):
    """Find combined area of two rectangles"""
    return r1.area() + r2.area()

# %%
rect_1 = Rectangle(12, 27)
rect_2 = Rectangle(9, 3)
combined_area = Rectangle.combined_area(rect_1, rect_2)
print(combined_area)
# Out:
# 351

# %% [markdown]
# **Call the combined_area method from the instance rect_1 with rect_1 and rect_2 as parameters**

# %%
rect_1 = Rectangle(12, 27)
rect_2 = Rectangle(9, 3)
combined_area = rect_1.combined_area(rect_1, rect_2)
print(combined_area)
# Out:
# 351

# %% [markdown]
# **Why does this work?**
#
# Like class methods, static methods can be called from the class itself or from an instance of a class.

# %% [markdown]
# #### Can static methods be used for factory methods?
#
# * Yes, using the @staticmethod decorator for factory methods will not cause an error.
# * However, the Python community decided to use the @classmethod decorator when making factory methods. This community-based decision is called **a convention**.
# * Code that does not follow convention will still run, but it is not considered to be "proper" Python.

# %% [markdown]
# **Summary**
# * Instance methods do not have a decorator.
# * Static methods do not have a special parameter.
# * Class methods require the parameter `cls`.
# * Instance methods require the parameter `self`.
# * Static methods require the decorator `@staticmethod`
# * Class methods require the decorator `@classmethod`.

# %% [markdown]
# ## What is Inheritance?
# **One class copies the attributes and methods from another class.**
#
# **Example:**
# * Imagine you want to create two Python classes, Person and Superhero.

# %%
class Person:
  def __init__(self, name, age, occupation):
    self.name = name
    self.age = age
    self.occupation = occupation

  def say_hello(self):
    print(f"Hello, my name is {self.name}.")

  def say_age(self):
    print(f"I am {self.age} years old.")

# %%
class Superhero:
  def __init__(self, name, age, occupation, secret_identity, namesis):
    self.name = name
    self.age = age
    self.occupation = occupation
    self.secret_identity = secret_identity
    self.namesis = namesis

  def say_hello(self):
    print(f"Hello, my name is {self.name}.")

  def say_age(self):
    print(f"I am {self.age} years old.")

  def reveal_secret_identity(self):
    print(f"My secret identiry is: {self.secret_identity}")

# %% [markdown]
# * There are some similarities between the Person class and the Superhero class.
#
# * If the Person class already exists, it would be helpful to “borrow” from the Person class so you only have to create the new attributes and methods for the Superhero class.

# %%
class Superhero(Person):
  pass

hero = Superhero("Jessica Jones", 29, "private investigator")
print(hero.name)
print(hero.occupation)
# Out:
# Jessica Jones
# private investigator

# %% [markdown]
# The Superhero class can access the attributes of the Person class because Superheor inherits from Person.

# %%
# Print the age attribute for the hero object.
hero.age
# Out:
# 29

# %%
# Call the say_hello method with the hero object.
hero.say_hello()
# Out:
# Hello, my name is Jessica Jones.

# %% [markdown]
# **How to check inheritance of a class?**
#
# Python has a function called help which can aid you in understanding what is being inherited.

# %%
help(Superhero)
# Out:
# Help on class Superhero in module __main__:
#
# class Superhero(Person)
#  |  Superhero(name, age, occupation)
#  |
#  |  Method resolution order:
#  |      Superhero
#  |      Person
#  |      builtins.object
#  |
#  |  Methods inherited from Person:
#  |
#  |  __init__(self, name, age, occupation)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  say_age(self)
#  |
#  |  say_hello(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Person:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# * The first section is Method resolution order. This shows the steps Python takes with inheritance.
# * Python first starts with the Superhero class. So when you say print(hero.name),
# > * Python will look to the Superhero class for the attribute name.
# > * This does not exist. So Python moves to the next step, which is the Person class.
# >* Since the Person class has a name attribute, Python can stop here.

# %%
help(Person)
# Out:
# Help on class Person in module __main__:
#
# class Person(builtins.object)
#  |  Person(name, age, occupation)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name, age, occupation)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  say_age(self)
#  |
#  |  say_hello(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# **Why does the Person class inherit from builtins.object class?**
#
# * In Python, all classes inherit from the objects class.
# * It is not necessary to write class Person(object): when declaring a class
# * Python will perform the inheritance automatically.

# %% [markdown]
# ### The super( ) Keyword
#
# Another way to call a method from the parent class (sometimes called the super class), is to use the super() keyword.

# %%
class Superhero(Person):
  pass

hero = Superhero("Wonder Woman", 27, "intelligence officer")
hero.say_hello()
# Out:
# Hello, my name is Wonder Woman.

# %%
class Superhero(Person):
  def say_hello(self):
    super().say_hello()

hero = Superhero("Wonder Woman", 27, "intelligence officer")
hero.say_hello()
# Out:
# Hello, my name is Wonder Woman.

# %% [markdown]
# * The Superhero class has a method called say_hello.
# * The super() keyword tells Python to go to the parent class; the .say_hello() tells Python to call this method.
# * So super().say_hello() is calling say_hello from the Person class.

# %% [markdown]
# **Declare the function say_age for the Superhero class using inheritance.**

# %%
class Superhero(Person):
  pass

hero = Superhero("Wonder Woman", 27, "intelligence officer")
hero.say_hello()
hero.say_age()
# Out:
# Hello, my name is Wonder Woman.
# I am 27 years old.

# %%
class Superhero(Person):
  def say_hello(self):
    super().say_hello()

  def say_age(self):
    super().say_age()

hero = Superhero("Wonder Woman", 27, "intelligence officer")
hero.say_hello()
hero.say_age()
# Out:
# Hello, my name is Wonder Woman.
# I am 27 years old.

# %% [markdown]
# ### super( ) and `__init__`
#
# **If the super( ) keyword is used to call methods from the parent class, how come super( ) was not used with the `__init__` method?**
#
# * A child class will automatically inherit the `__init__` method if it is not defined.
# * `__init__` is called when an object is instantiated, and super( ) does not need to be used.
# *  it is possible to create an `__init__` method for the Superhero class using super( ).

# %%
class Superhero(Person):
  def __init__(self, name, age, occupation):
    super().__init__(name, age, occupation)

hero = Superhero("Batman", 32, "CEO")
print(hero.name)
# Out:
# Batman

# %% [markdown]
#  **The lack of `self` in `super().__init__`**
#
#  * It is because you were not defining the `__init__` method of the parent class, you were calling it.
#  * Just like any other method in Python, self is the first parameter when you declare a method, but it is not used when call the method.
#  * This is the first time that we are explicitly called the `__init__` method.

# %% [markdown]
# **Using the super( ) keyword, create the method say_two_things for the Superhero class. This method should print the name and age of the hero object.**

# %%
class Superhero(Person):
  def say_two_things(self):
    super().say_hello()
    super().say_age()

hero = Superhero("Rorschach", 34, "conspiracy theorist")
hero.say_two_things()
# Out:
# Hello, my name is Rorschach.
# I am 34 years old.

# %% [markdown]
# ### Inheritance Hierarchy
# * The relationship between these two classes is called inheritance (or class) hierarchy.
# * Python has some built-in functions to help you determine the hierarchy of classes.
# > * The first function is isinstance. This function takes an object and a class name. It returns True if the object is an instance of the class. The isinstance function can be used to test these relationships.

# %%
class ClassA:
  pass

class ClassB(ClassA):
  pass

class ClassC:
  pass

class ClassD(ClassC):
  pass

object_a = ClassA()
object_b = ClassB()
object_c = ClassC()
object_d = ClassD()

# %%
print(isinstance(object_b, ClassA))
print(isinstance(object_d, ClassC))
# Out:
# True
# True

# %%
print(isinstance(object_b, ClassC))
print(isinstance(object_d, ClassA))
print(isinstance(object_a, ClassA))
print(isinstance(object_d, ClassA))
print(isinstance(object_c, ClassB))
# Out:
# False
# False
# True
# False
# False

# %% [markdown]
# #### Is a Subclass?
#
# * Another function that can be used to determine inheritance hierarchy is issubclass.
# * This function takes a class and a class name. It returns true if the class is a subclass (or child) of the class name.
# > * This is very similar to isinstance, but the difference is important. issubclass checks to see if a class (not an object) is the child of another class.

# %%
print(issubclass(ClassB, ClassA))
print(issubclass(ClassD, ClassC))
# Out:
# True
# True

# %%
print(issubclass(ClassD, ClassA))
print(issubclass(ClassA, ClassB))
# Out:
# False
# False

# %%
print(issubclass(object_b, ClassA))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-2131fe072654> in <cell line: 1>()
# ----> 1 print(issubclass(object_b, ClassA))
#
# TypeError: issubclass() arg 1 must be a class

# %% [markdown]
# An error because issubclass requires two classes as parameters. object_b is an instance of a class, not a class itself.

# %% [markdown]
# ### Extending the `__init__` Method
#
# * The idea of inheritance is to borrow from a parent class and then add on functionality.
# * The process of adding functionality to a child class is known as either extending or overriding.
# * Extending a class means that new attributes and methods are given to the child class.

# %%
class Superhero(Person):
  def __init__(self, name, age, occupation, secret_identity):
    super().__init__(name, age, occupation)
    self.secret_identity = secret_identity

hero = Superhero("Spider-Man", 17, "student", "Peter Parker")
print(hero.secret_identity)
# Out:
# Peter Parker

# %% [markdown]
# * Call the `__init__` method (using super()) of the parent class to create the attributes name, age, and occupation.
# * The __init__ method is extended when the attribute secret_identity is added to the Superhero class.

# %% [markdown]
# **Is inheritance a one way road?**
#
# * Yes, inheritance shares attributes and methods from the parent class to the child class.
# * When a child class is extended, it cannot share the new additions with their parent class.
# * **Example:** In the code above, Superhero has access to name, but Person does not have access to secret_identity.

# %% [markdown]
# **Rewrite the Superhero class so that it extends the Person class by adding the attribute nemesis, Doc Octopus.**

# %%
class Superhero(Person):
  def __init__(self, name, age, occupation, secret_identity, nemesis):
    super().__init__(name, age, occupation)
    self.secret_identity = secret_identity
    self.nemesis = nemesis

hero = Superhero("Spider-Man", 17, "student", "Peter Parker", "Doc Octopus")
print(hero.nemesis)
# Out:
# Doc Octopus

# %% [markdown]
# ### Extending a Class by Adding New Methods
#
# * Another way to extend a class is to create new methods that are unique to the child class.
# * For example, the say_hello method will give the superhero’s name, but it will not divulge their secret identity.
# * Create the method reveal_secret_identity to print the attribute secret_identity.

# %%
class Superhero(Person):
  def __init__(self, name, age, occupation, secret_identity, nemesis):
    super().__init__(name, age, occupation)
    self.secret_identity = secret_identity

  def reveal_secret_identity(self):
    print(f"My real name is {self.secret_identity}.")

hero = Superhero("Spider-Man", 17, "student", "Peter Parker", "Doc Octopus")
hero.reveal_secret_identity()
# Out:
# My real name is Peter Parker.

# %% [markdown]
# #### Method Overriding
#
# * Another way to add new functionality to a child class is through method overriding.
# * Overriding a method means to inherit a method from the parent class, keep its name, but change the contents of the method.
#
# **Extend the Superhero class by overriding the say_hello. Make a new instance of the class and call the method.**

# %%
class Person:
  def __init__(self, name, age, occupation):
    self.name = name
    self.age = age
    self.occupation = occupation

  def say_hello(self):
    print(f"Hello, my name is {self.name}.")

  def say_age(self):
    print(f"I am {self.age} years old.")

class Superhero(Person):
  def __init__(self, name, age, occupation, secret_identity, nemesis):
    super().__init__(name, age, occupation)
    self.secret_identity = secret_identity

  def say_hello(self):
    print(f"I am {self.name}, and criminals fear me.")

  def reveal_secret_identity(self):
    print(f"My real name is {self.secret_identity}.")

  def say_nemesis(self):
    print(f"My nemesis is {self.nemesis}.")

# %%
hero = Superhero("Storm", "30", "Queen of Wakanda", "Ororo Munroe", "Shadow King")
hero.say_hello()
# Out:
# I am Storm, and criminals fear me.

# %% [markdown]
# **Override the say_age method so that it prints the string: Young or old, I will triumph over evil.**

# %%
class Person:
  def __init__(self, name, age, occupation):
    self.name = name
    self.age = age
    self.occupation = occupation

  def say_hello(self):
    print(f"Hello, my name is {self.name}.")

  def say_age(self):
    print(f"I am {self.age} years old.")

class Superhero(Person):
  def __init__(self, name, age, occupation, secret_identity, nemesis):
    super().__init__(name, age, occupation)
    self.secret_identity = secret_identity

  def say_hello(self):
    print(f"I am {self.name}, and criminals fear me.")

  def say_age(self):
    print(f'Young or old I will trimph over evil')

  def reveal_secret_identity(self):
    print(f"My real name is {self.secret_identity}.")

  def say_nemesis(self):
    print(f"My nemesis is {self.nemesis}.")

# %%
hero = Superhero('Storm', 30, 'Queen of Wakanda', 'Oro Monroe', 'Shadow King')
hero.say_hello()
hero.say_age()
# Out:
# I am Storm, and criminals fear me.
# Young or old I will trimph over evil

# %% [markdown]
# **What Happens When You Override a Method?**
#
# Using the help function, we can see a graphical representation of the parent and child classes.

# %%
help(Superhero)
# Out:
# Help on class Superhero in module __main__:
#
# class Superhero(Person)
#  |  Superhero(name, age, occupation, secret_identity, nemesis)
#  |
#  |  Method resolution order:
#  |      Superhero
#  |      Person
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name, age, occupation, secret_identity, nemesis)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  reveal_secret_identity(self)
#  |
#  |  say_age(self)
#  |
#  |  say_hello(self)
#  |
#  |  say_nemesis(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Person:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# Notice that there is no section that says Methods inherited from Person
#
# **Does that mean that the Superhero can no longer use the original say_age and say_hello methods?**
#
# * No, the child class can still call the methods from the parent class.
# * However, calling say_hello or say_age will not print the same string as the parent class.
# * Instead, using the super() keyword gives a child class access to the original methods.

# %%
class Person:
  def __init__(self, name, age, occupation):
    self.name = name
    self.age = age
    self.occupation = occupation

  def say_hello(self):
    print(f"Hello, my name is {self.name}.")

  def say_age(self):
    print(f"I am {self.age} years old.")

class Superhero(Person):
  def __init__(self, name, age, occupation, secret_identity, nemesis):
    super().__init__(name, age, occupation)
    self.secret_identity = secret_identity

  def say_hello(self):
    print(f"I am {self.name}, and criminals fear me.")

  def old_say_hello(self):
    super().say_hello()

  def say_age(self):
    print(f'Young or old I will trimph over evil')

  def reveal_secret_identity(self):
    print(f"My real name is {self.secret_identity}.")

  def say_nemesis(self):
    print(f"My nemesis is {self.nemesis}.")

# %%
hero = Superhero('Storm', 30, 'Queen of Wakanda', 'Oro Monroe', 'Shadow King')
hero.old_say_hello()
# Out:
# Hello, my name is Storm.

# %% [markdown]
# **Add the method old_say_age to the Superhero class and then call it.**

# %%
class Person:
  def __init__(self, name, age, occupation):
    self.name = name
    self.age = age
    self.occupation = occupation

  def say_hello(self):
    print(f"Hello, my name is {self.name}.")

  def say_age(self):
    print(f"I am {self.age} years old.")

class Superhero(Person):
  def __init__(self, name, age, occupation, secret_identity, nemesis):
    super().__init__(name, age, occupation)
    self.secret_identity = secret_identity

  def say_hello(self):
    print(f"I am {self.name}, and criminals fear me.")

  def old_say_hello(self):
    super().say_hello()

  def say_age(self):
    print(f'Young or old I will trimph over evil')

  def old_say_age(self):
    super().say_age()

  def reveal_secret_identity(self):
    print(f"My real name is {self.secret_identity}.")

  def say_nemesis(self):
    print(f"My nemesis is {self.nemesis}.")

# %%
hero = Superhero('Storm', 30, 'Queen of Wakanda', 'Oro Monroe', 'Shadow King')
hero.old_say_age()
# Out:
# I am 30 years old.

# %% [markdown]
# * Method overriding happens when the child class has a method with the same name as the parent class, but the child’s method does something different.
# * Extending a class happens when new attributes or methods are added to the child class that do not exist in the parent class.

# %% [markdown]
# ### Multiple Inheritance
# * Inheritance has been introduced as there being only one parent class.
# * Multiple inheritance is when there are more than one parent class.
# * In single inheritance, the parent class appears between parentheses. For multiple inheritance, put both parent classes between parentheses.

# %%
class Dinosaur:
  def __init__(self, size, weight):
    self.size = size
    self.weight = weight

class Carnivore:
  def __init__(self, diet):
    self.diet = diet

class Tyrannosaurus(Dinosaur, Carnivore):
  pass

# %% [markdown]
# **What does pass do?**
#
# Python expects there to be code in the body of the Tyrannosaurus class. However, we just want this class to inherit from its parents. Using pass satisfies Python's need to have a body for the class, but pass doesn't do anything.

# %%
tiny = Tyrannosaurus(12, 14, "whatever it wants")
print(tiny.size)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-f59c864bad9a> in <cell line: 1>()
# ----> 1 tiny = Tyrannosaurus(12, 14, "whatever it wants")
#       2 print(tiny.size)
#
# TypeError: Dinosaur.__init__() takes 3 positional arguments but 4 were given

# %% [markdown]
# * In multiple inheritance, there are two `__init__` methods (one from each parent) that the class Tyrannosaurus inherits.
# * Python is not sure how to take the list of parameters for tiny and divide them between the two `__init__` methods.

# %%
tiny = Tyrannosaurus(12, 14)
print(tiny.size)
# Out:
# 12

# %% [markdown]
# **Why does it work now?**
#
# The Tyrannosaurus class inherits from two classes. One parent has two parameters for its constructor, while the other has one parameter. Python throws an error when three parameters are passed to Tyrannosaurus, but runs just fine when two parameters are passed.

# %%
class Tyrannosaurus(Dinosaur, Carnivore):
  pass

# %% [markdown]
# Dinosaur is listed as the first parent class, so Python uses the constructor from the Dinosaur class. Since Dinosaur takes two parameters, the Tyrannosaurus class works with two parameters.

# %% [markdown]
# **Change the order of the parent classes when defining the Tyrannosaurus class. Instantiate an instance as, tiny = Tyrannosaurus("whatever it wants"). Finally, print out the diet attribute.**

# %%
class Tyrannosaurus(Carnivore, Dinosaur):
    pass

# %%
tiny = Tyrannosaurus("whatever it wants")
print(tiny.diet)
# Out:
# whatever it wants

# %% [markdown]
# #### Overriding the `__init__` Method
#
# In order to have access to the attributes from all the parent classes, you need to override the `__init__` method of the child class. Previously, you used the super() keyword to refer to methods in the parent class. This will not work for multiple inheritance.

# %%
class Tyrannosaurus(Dinosaur, Carnivore):
  def __init__(self, size, weight, diet):
    super().__init__(size, weight)
    super().__init__(diet)

# %%
tiny = Tyrannosaurus(12, 14, "whatever it wants")
tiny
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-42a91c2aeeb8> in <cell line: 1>()
# ----> 1 tiny = Tyrannosaurus(12, 14, "whatever it wants")
#       2 tiny
#
# <ipython-input-55-8d8ccef00754> in __init__(self, size, weight, diet)
#       2   def __init__(self, size, weight, diet):
#       3     super().__init__(size, weight)
# ----> 4     super().__init__(diet)
#
# TypeError: Dinosaur.__init__() missing 1 required positional argument: 'weight'

# %% [markdown]
# * Python does not know if super() is referring to the Dinosaur class or the Carnivore class.
# * Overriding the `__init__` method for multiple inheritance requires a unique structure.
# * Instead of super() use the name of the class. You must also pass self to the parent `__init__` method.

# %%
class Dinosaur:
  def __init__(self, size, weight):
    self.size = size
    self.weight = weight

class Carnivore:
  def __init__(self, diet):
    self.diet = diet

class Tyrannosaurus(Dinosaur, Carnivore):
  def __init__(self, size, weight, diet):
    Dinosaur.__init__(self, size, weight)
    Carnivore.__init__(self, diet)

# %%
tiny = Tyrannosaurus(12, 14, "whatever it wants")
tiny

# %% [markdown]
# **Verify that the `__init__` method has been overridden by printing out the size, weight, and diet attributes for tiny.**

# %%
tiny = Tyrannosaurus(12, 14, "whatever it wants")
print(tiny.size)
print(tiny.weight)
print(tiny.diet)
# Out:
# 12
# 14
# whatever it wants

# %% [markdown]
# #### Multiple Inheritance Hierarchy
# **Is an Instance or is a Subclass?**
# * Like single inheritance, the isinstance function works with with multiple inheritance.
# > * The code below prints True if obj is an instance of the D class.
# > * It will print False if obj is not an instance of D.

# %%
class A:
  pass

class B:
  pass

class C:
  pass

class D(A, B):
  pass

obj= D()
print(isinstance(obj, D))
print(issubclass(D, A))
# Out:
# True
# True

# %%
print(isinstance(obj, A))
# Out:
# True

# %%
print(isinstance(obj, B))
# Out:
# True

# %%
print(isinstance(obj, C))
# Out:
# False

# %%
print(issubclass(D, B))
# Out:
# True

# %%
print(issubclass(D, C))
# Out:
# False

# %% [markdown]
# ### Method Resolution Order
#
# **However, there are two parent classes. What do you think the result will be?**

# %%
class A:
  def hello(self):
    print("Hello from class A")

class B:
  def hello(self):
    print("Hello from class B")

class C(A, B):
  def hello(self):
    super().hello()

obj= C()
obj.hello()
# Out:
# Hello from class A

# %% [markdown]
# * Class C is the subclass of A and B. Both parent classes have a method called hello which prints either Hello from class A or Hello from class B.
# * Class C overrides hello and calls super().hello(). The keyword super() refers to the hello method of the parent class.

# %% [markdown]
# **If super() cannot be used when overriding the __init__ method, why does Python print Hello from class A and not an error message?**
#
# * Python has something called method resolution order (MRO).
# * MRO is the way Python looks for methods in parent classes.

# %%
obj= C()
print(C.mro())
# Out:
# [<class '__main__.C'>, <class '__main__.A'>, <class '__main__.B'>, <class 'object'>]

# %% [markdown]
# **The order of objects in the list represents the order Python uses to search for a method.**
#
# * So when class C says super().hello(), Python skips class C because of the super() keyword.
# * Then it moves on to class A. The hello method is present in class A, so it prints Class A.
# * Then Python stops searching the rest of the classes, which why Class B is not printed even though the hello method is present in class B.

# %% [markdown]
# **Change the definition for class C so that B comes before A. Then print the output of the mro() method on class C.**

# %%
class C(B, A):
  def describe(self):
    super().hello()

print(C.mro())
# Out:
# [<class '__main__.C'>, <class '__main__.B'>, <class '__main__.A'>, <class 'object'>]

# %% [markdown]
# * MRO is defined by the order of parent classes.
# > * So class C(A, B): puts class A before class B.
# > * Writing class C(B, A): will search class B before class `A.
#
# **Now that the MRO has been changed, call the hello method.**

# %%
obj.hello()
# Out:
# Hello from class A

# %% [markdown]
# **What is the method resolution order (MRO) for class Three?**

# %%
class One:
  def example_method_one(self):
    return "I am from class One"

class Two:
  def example_method_two(self):
    return "I am from class Two"

class Three(Two, One):
  def example_method_three(self):
    return "I am from class Three"

# %%
Three.mro()
# Out:
# [__main__.Three, __main__.Two, __main__.One, object]

# %% [markdown]
# * The method resolution order always starts with the base class itself, so Three is first.
# * The rest of the order is decided by the order of the parent classes in between the parentheses.
# * So Three is followed by Two and One.
# * All classes in Python are a child of the object class. The object class is always the last class in method resolution order.

# %% [markdown]
# #### Extending and Overriding Methods
#
# Multiple inheritance has no effect on extending a child class. The bonjour method is not present in either parent class. There is no need for special syntax to extend C.

# %%
class A:
  def hello(self):
    print("Hello from class A")

class B:
  def hello(self):
    print("Hello from class B")

class C(A, B):
  def bonjour(self):
    print("Bonjour")

obj= C()
obj.bonjour()
# Out:
# Bonjour

# %% [markdown]
# **Extend C with the method goodbye that prints Goodbye. Then call this method.**

# %%
class A:
  def hello(self):
    print("Hello from class A")

class B:
  def hello(self):
    print("Hello from class B")

class C(A, B):
  def bonjour(self):
    print("Bonjour")

  def goodbye(self):
    print("Goodbye")

# %%
obj= C()
obj.goodbye()
# Out:
# Goodbye

# %% [markdown]
# #### Overriding a Method with Multiple Inheritance
#
# With the exception of the `__init__` method, overriding a method works the same in multiple inheritance as it does in single inheritance.

# %%
class A:
  def hello(self):
    print("Hello from class A")

class B:
  def hello(self):
    print("Hello from class B")

class C(A, B):
  def hello(self):
    print("Hello from class C")

# %%
obj= C()
obj.hello()
# Out:
# Hello from class C

# %% [markdown]
# * In single inheritance, you can use the super() keyword to invoke methods from the parent class.
# * Because of method resolution order, you can do the same thing with multiple inheritance.
# * The one exception is when both parent classes have a method with the same name.

# %%
class A:
  def hello(self):
    print("Hello from class A")

class B:
  def hello(self):
    print("Hello from class B")

class C(A, B):
  def hello(self):
    print("Hello from class C")
    super().hello()

# %%
obj= C()
obj.hello()
# Out:
# Hello from class C
# Hello from class A

# %% [markdown]
# * Because of MRO, super() refers to the hello method in class A.
# * To refer to the hello method in class B, you will use the same format as when you overrode the `__init__` method.

# %%
class A:
  def hello(self):
    print("Hello from class A")

class B:
  def hello(self):
    print("Hello from class B")

class C(A, B):
  def hello(self):
    print("Hello from class C")
    super().hello()
    B.hello(self)

# %%
obj= C()
obj.hello()
# Out:
# Hello from class C
# Hello from class A
# Hello from class B

# %% [markdown]
# ## Encapsulation
#
# Encapsulation is a concept in which related data and methods are grouped together, and in which **access to data is restricted**.
# * Grouping related data and methods makes thinking about your program a bit easier.
# * Hiding or restricting how the user interacts with the data can keep the user from making unwanted changes.
#
# The two main ideas of **data restriction are public and private**. These adjectives can refer to both attributes and methods.
# * Public means that the attribute or method can be accessed by an instance of a class.
# * Private means that the attribute or method can only be accessed by the class itself.
#
# **The instance of a class is not a part of the class itself; it is considered to be separate.**

# %% [markdown]
# **There are two main ideas behind encapsulation: grouping together related data and restricting this data. Each idea on its own can be an example of encapsulation. However, the best definition is one that includes grouping the data and restricting the data.**

# %% [markdown]
# **By default, classes in Python do not hide or restrict access to data**

# %%
class Phone:
  def __init__(self, make, storage, megapixels):
    self.make = make
    self.storage = storage
    self.megapixels = megapixels

my_phone = Phone("iPhone", 256, 12)
print(my_phone.make)
print(my_phone.storage)
print(my_phone.megapixels)
# Out:
# iPhone
# 256
# 12

# %% [markdown]
# **A traditional class in Python does not provide any restrictions to accessing data because everything is public by default. Any instance of the Phone class can change its attributes.**

# %%
my_phone = Phone("iPhone", 256, 12)
print(my_phone.storage)
my_phone.storage = 64
print(my_phone.storage)
# Out:
# 256
# 64

# %%
my_phone.model = True

# %%
my_phone.storage = '256GB'

# %%
my_phone.megapixels = -32

# %%
my_phone.__dict__
# Out:
# {'make': 'iPhone', 'storage': '256GB', 'megapixels': -32, 'model': True}

# %% [markdown]
# **Why restrict data access?**
# * Having public instance variables might not seem like a bad idea.
# * The three variations you just coded either changed the data type or changed the value to something that does not make sense given the current context
# * Because these instance variables now have unexpected values or data types, you may see bugs appear in your code.
# * **Public instance variables increase the possibility for errors.**

# %% [markdown]
# ### Encapsulation Through Convention
# * Python community relies on a convention to signify private methods and instance variables.
# * When programmers use a single underscore (_) before an attribute or method name, that attribute or method is considered to be private.

# %%
class Phone:
  def __init__(self, model, storage, megapixels):
    self._model = model
    self._storage = storage
    self._megapixels = megapixels

# %%
class Phone:
  def __init__(self, model, storage, megapixels):
    self._model = model
    self._storage = storage
    self._megapixels = megapixels

my_phone = Phone("iPhone", 256, 12)
print(my_phone.__dict__)
# Out:
# {'_model': 'iPhone', '_storage': 256, '_megapixels': 12}

# %% [markdown]
# Extend the Phone class by adding the private attribute _carrier. Instantiate the object with the string "AT&T". Print the __dict__ attribute to make sure your code worked properly.

# %%
class Phone:
  def __init__(self, model, storage, megapixels, carrier):
    self._model = model
    self._storage = storage
    self._megapixels = megapixels
    self._carrier = carrier

my_phone = Phone("iPhone", 256, 12, "AT&T")
print(my_phone.__dict__)
# Out:
# {'_model': 'iPhone', '_storage': 256, '_megapixels': 12, '_carrier': 'AT&T'}

# %% [markdown]
# **Does the Single Underscore Really Mean Private?**
#
# **No.**
# * The single underscore is a convention. That is, an informal agreement to recognize that attributes and methods with a single underscore are private.
# * *The Python interpreter does not enforce any restrictions that make these attributes private.*

# %%
class PrivateClass:
  def __init__(self):
    self._private_attribute = "I am a private attribute"

obj = PrivateClass()
print(obj._private_attribute)
# Out:
# I am a private attribute

# %% [markdown]
# * If _private_attribute really were private, Python would throw an error message. Instead, Python sees _private_attribute as being public and prints its value.
# * Python does not have truly private attributes and methods, though Python can approximate this behavior.

# %% [markdown]
# **Create the method _private_method that returns the string "I am a private method". Call this method from outside the class.**

# %%
class PrivateClass:
  def __init__(self):
    self._private_attribute = "I am a private attribute"

  def _private_method(self):
    return "I am a private method"

obj = PrivateClass()
print(obj._private_method())
# Out:
# I am a private method

# %% [markdown]
# ### Private Attributes - Double Underscore
# * **Python gives you an approximation of private attributes when using double underscores.**
# * When you have a single underscore, the Python interpreter does not do anything. It is just a convention. Using two underscores, however, causes the Python interpreter to enforce changes.

# %%
class PrivateClass:
  def __init__(self):
    self.__private_attribute = "I am a private attribute"

obj = PrivateClass()
print(obj.__private_attribute)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-6b1d3753ec43> in <cell line: 6>()
#       4
#       5 obj = PrivateClass()
# ----> 6 print(obj.__private_attribute)
#
# AttributeError: 'PrivateClass' object has no attribute '__private_attribute'

# %% [markdown]
# Python does not allow you to access __private_attribute from outside the class. Instead, let’s **add a helper method to the class that will return __private_attribute for us**.

# %%
class PrivateClass:
  def __init__(self):
    self.__private_attribute = "I am a private attribute"

  def helper_method(self):
    return self.__private_attribute

obj = PrivateClass()
print(obj.helper_method())
# Out:
# I am a private attribute

# %% [markdown]
# #### Private Methods
# **Use the double underscores to restrict access to methods.**

# %%
class PrivateClass:
  def __init__(self):
    self.__private_attribute = "I am a private attribute"

  def __private_method(self):
    return "I am a private method"

obj = PrivateClass()
print(obj.__private_method())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-89779e47cb9c> in <cell line: 9>()
#       7
#       8 obj = PrivateClass()
# ----> 9 print(obj.__private_method())
#
# AttributeError: 'PrivateClass' object has no attribute '__private_method'

# %% [markdown]
# Create the method helper_method that calls __private_method and call this method outside of the class.

# %%
class PrivateClass:
  def __init__(self):
    self.__private_attribute = "I am a private attribute"

  def __private_method(self):
    return "I am a private method"

  def helper_method(self):
    return self.__private_method()

obj = PrivateClass()
print(obj.helper_method())
# Out:
# I am a private method

# %%
obj.__dict__
# Out:
# {'_PrivateClass__private_attribute': 'I am a private attribute'}

# %% [markdown]
# **Are Double Underscores Really Private?**
#
# **No.**
# * Double underscores were not added to the Python language to promote encapsulation.
# * Rather, the double underscore is used to avoid name collisions in inheritance.

# %%
class PrivateClass:
  def __init__(self):
    self.__private_attribute = "I am a private attribute"

obj = PrivateClass()
print(obj._PrivateClass__private_attribute)
# Out:
# I am a private attribute

# %% [markdown]
# When the Python interpreter encounters an attribute with a double underscore, it does not make it private. Instead, it changes the name to _ClassName__AttributeName.
#
# **This whole process is called name mangling, and it is designed to avoid name collisions in inheritance.** Name mangling, however, gives the appearance of private attributes and methods.

# %% [markdown]
# ### Getters and Setters
#
# **Assume that programmers are respecting the convention** that a single underscore makes an attribute private. Getters and setters are then used to access and manipulate these attributes.
# * Getters (sometimes called accessors) are used to return a private attribute, and
# * Setters (sometimes called mutators) are used to update the value of a private attribute.

# %% [markdown]
# **Why are they called getters and setters?**
#
# * The name getter comes from the fact that many programmers write a method that starts with get_ followed by the attribute name.
# * Similarly, the name setter comes from programmers write a method that starts with set_ followed by the attribute name.

# %%
class Phone:
  def __init__(self, model, storage, megapixels):
    self._model = model
    self._storage = storage
    self._megapixels = megapixels

  def get_model(self):
    return self._model

  def set_model(self, new_model):
    self._model = new_model

my_phone = Phone("iPhone", 256, 12)
print(my_phone.get_model())
my_phone.set_model("Galaxy S20")
print(my_phone.get_model())
# Out:
# iPhone
# Galaxy S20

# %% [markdown]
# * The get_model (a getter) acts as an intermediary between the user (outside the class) and the private attribute _model (inside the class).
# * Similarly, the user invokes set_model (a setter) to update the “private” attribute _model.

# %% [markdown]
# **Write getters and setters for all of the instance variables in the Phone class.**
#
# * Getter methods should return the attribute, while setter methods should update the attribute with a new value.

# %%
class Phone:
  def __init__(self, model, storage, megapixels):
    self._model = model
    self._storage = storage
    self._megapixels = megapixels

  def get_model(self):
    return self._model

  def get_storage(self):
    return self._storage

  def get_megapixels(self):
    return self._megapixels

  def set_model(self, new_model):
    self._model = new_model

  def set_storage(self, new_storage):
    self._storage = new_storage

  def set_megapixels(self, new_megapixels):
    self._megapixels = new_megapixels

# %% [markdown]
# #### Getters with the Property Decorator
#
# **The Property Class**
# * The property class in Python allows the programmer to use getters and setters in a pythonic way.
# * There are two ways to implement the property class.
# > * One way is with the @property decorator, and
# > * *The* second way is with the property function.

# %% [markdown]
# The end goal is to be able to reference `.name` as if it were a public attribute. Start by setting up the Person class with the getter name.

# %%
class Person:
  def __init__(self, name):
    self._name = name

  def name(self):
    return self._name

c = Person("Calvin")
print(c.name())
# Out:
# Calvin

# %% [markdown]
# * The program works as expected, but we want to get rid of the parentheses after name.
# * Python uses the @property decorator so that name assumes getter behavior.

# %%
class Person:
  def __init__(self, name):
    self._name = name

  @property
  def name(self):
    return self._name

c = Person("Calvin")
print(c.name)
# Out:
# Calvin

# %%
print(c.name())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-2039e6fa4c01> in <cell line: 1>()
# ----> 1 print(c.name())
#
# TypeError: 'str' object is not callable

# %% [markdown]
# * The @property decorator means name is treated as an instance variable and not a method. So c.name is the string "Calvin".
# * Adding the parentheses to c.name means you are trying to "call" the string. You can call a method or a function, but you cannot call a string.

# %% [markdown]
# Modify the Person class such that:
# * there is the instance variable _age and the getter age to access this variable.
# * Create the instance c with the attributes "Calvin" and 6.
# * Print these attributes with the getter methods.

# %%
class Person:
  def __init__(self, name, age):
    self._name = name
    self._age = age

  @property
  def name(self):
    return self._name

  @property
  def age(self):
    return self._age

c = Person("Calvin", 6)
print(c.name)
print(c.age)
# Out:
# Calvin
# 6

# %% [markdown]
# #### Setters with the Property Decorator
#
# * Setters can also take the @property decorator, but its implementation is different from the getter.
# * The setter decorator starts with a @ followed by the name of the getter method, and it ends with .setter.
# * So if the getter is called name, the setter decorator is `@name.setter`.

# %%
class Person:
  def __init__(self, name):
    self._name = name

  @property
  def name(self):
    return self._name

  @name.setter
  def name(self, new_name):
    self._name = new_name

c = Person("Calvin")
print(c.name)
c.name = "Hobbes"
print(c.name)
# Out:
# Calvin
# Hobbes

# %% [markdown]
# **It appears as though the programmer is directly manipulating the instance variable name. In reality, however, getters and setters are acting as an intermediary between the programmer and the private attribute _name.**

# %% [markdown]
# Comment out the @property decorator and run the code.

# %%
class Person:
  def __init__(self, name):
    self._name = name

  # @property
  def name(self):
    return self._name

  @name.setter
  def name(self, new_name):
    self._name = new_name

c = Person("Calvin")
print(c.name)
c.name = "Hobbes"
print(c.name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-31d2613be055> in <cell line: 1>()
# ----> 1 class Person:
#       2   def __init__(self, name):
#       3     self._name = name
#       4
#       5   # @property
#
# <ipython-input-27-31d2613be055> in Person()
#       7     return self._name
#       8
# ----> 9   @name.setter
#      10   def name(self, new_name):
#      11     self._name = new_name
#
# AttributeError: 'function' object has no attribute 'setter'

# %% [markdown]
# * When you use the @property decorator, Python is actually making a property object. This object has a .setter method.
# * If @property is commented out, there is no property object. So Python assumes that .setter is a method on the @name class, but that class does not exist.

# %% [markdown]
# #### Data Validation
#
#  * Data validation is the process of asking if this data is appropriate for its intended use.
#  * Setters allow you to validate the data before changing the object.

# %%
class Person:
  def __init__(self, name, age):
    self._name = name
    self._age = age

  @property
  def name(self):
    return self._name

  @name.setter
  def name(self, new_name):
    self._name = new_name

  @property
  def age(self):
    return self._age

  @age.setter
  def age(self, new_age):
    self._age = new_age

c = Person("Calvin", "6")
print(c.name)
print(c.age)
c.age = -17
c.name = False
print(c.name)
print(c.age)
# Out:
# Calvin
# 6
# False
# -17

# %% [markdown]
# **Modify the setter for name so that it checks to see the data type of new_name is not a string**

# %%
class Person:
  def __init__(self, name, age):
    self._name = name
    self._age = age

  @property
  def name(self):
    return self._name

  # @name.setter
  # def name(self, new_name):
  #   self._name = new_name

  @name.setter
  def name(self, new_name):
    if type(new_name) != str:
      raise TypeError("Names must be expressed as a string")
    self._name = new_name

  @property
  def age(self):
    return self._age

  @age.setter
  def age(self, new_age):
    self._age = new_age

c = Person("Calvin", "6")
print(c.name)
print(c.age)
c.age = -17
c.name = False
print(c.name)
print(c.age)
# Out:
# Calvin
# 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-c4be459e6e6b> in <cell line: 32>()
#      30 print(c.age)
#      31 c.age = -17
# ---> 32 c.name = False
#      33 print(c.name)
#      34 print(c.age)
#
# <ipython-input-30-c4be459e6e6b> in name(self, new_name)
#      15   def name(self, new_name):
#      16     if type(new_name) != str:
# ---> 17       raise TypeError("Names must be expressed as a string")
#      18     self._name = new_name
#      19
#
# TypeError: Names must be expressed as a string

# %%
class Person:
  def __init__(self, name, age):
    self._name = name
    self._age = age

  @property
  def name(self):
    return self._name

  # @name.setter
  # def name(self, new_name):
  #   self._name = new_name

  @name.setter
  def name(self, new_name):
    if type(new_name) != str:
      raise TypeError("Names must be expressed as a string")
    self._name = new_name

  @property
  def age(self):
    return self._age

  # @age.setter
  # def age(self, new_age):
  #   self._age = new_age

  @age.setter
  def age(self, new_age):
    if new_age < 0:
      raise ValueError("Age must be a positive number.")
    self._age = new_age

c = Person("Calvin", "6")
print(c.name)
print(c.age)
c.age = -17
c.name = False
print(c.name)
print(c.age)
# Out:
# Calvin
# 6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-090f2cbbe5f3> in <cell line: 37>()
#      35 print(c.name)
#      36 print(c.age)
# ---> 37 c.age = -17
#      38 c.name = False
#      39 print(c.name)
#
# <ipython-input-31-090f2cbbe5f3> in age(self, new_age)
#      29   def age(self, new_age):
#      30     if new_age < 0:
# ---> 31       raise ValueError("Age must be a positive number.")
#      32     self._age = new_age
#      33
#
# ValueError: Age must be a positive number.

# %% [markdown]
# #### Getters with the Property Function
#
# * The getter ans setter functionality can be added by using the property method. Start with the Person class.
# * Remove the @property decorator and change the name of the getter to get_name.

# %%
class Person:
  def __init__(self, name):
    self._name = name

  def get_name(self):
    return self._name

# %% [markdown]
# Since `name` will be used as the getter and setter, create the variable name and set its value to `property(get_name)`.

# %%
class Person:
  def __init__(self, name):
    self._name = name

  def get_name(self):
    return self._name

  name = property(get_name)

c = Person("Calvin")
print(c.name)
# Out:
# Calvin

# %% [markdown]
# Add the _age attribute to the Person class and create the getter get_age.

# %%
class Person:
  def __init__(self, name, age):
    self._name = name
    self._age = age

  def get_name(self):
    return self._name

  def get_age(self):
    return self._age

  name = property(get_name)
  age = property(get_age)

c = Person("Calvin", 6)
print(c.name)
print(c.age)
# Out:
# Calvin
# 6

# %% [markdown]
# #### Setters with the Property Function
#
# * Creating a setter is done in a similar manner. Create set_name as a method to update the _name attribute.
# * Then add set_name to the property function.
#
# **When adding the getter and setter to the property function, it is the getter that always goes first. The setter is always second.**

# %%
class Person:
  def __init__(self, name):
    self._name = name

  def get_name(self):
    return self._name

  def set_name(self, new_name):
    self._name = new_name

  name = property(get_name, set_name)

c = Person("Calvin")
print(c.name)
c.name = "Hobbes"
print(c.name)
# Out:
# Calvin
# Hobbes

# %% [markdown]
# Add the _age attribute to the Person class and create a getter and a setter. Change _name to "Hobbes" and _age to 8.

# %%
class Person:
  def __init__(self, name, age):
    self._name = name
    self._age = age

  def get_name(self):
    return self._name

  def set_name(self, new_name):
    self._name = new_name

  def get_age(self):
    return self._age

  def set_age(self, new_age):
    self._age = new_age

  name = property(get_name, set_name)
  age = property(get_age, set_age)

c = Person("Calvin", 6)
print(c.name)
print(c.age)
c.name = "Hobbes"
c.age = 8
print(c.name)
print(c.age)
# Out:
# Calvin
# 6
# Hobbes
# 8

# %% [markdown]
# ## Polymorphism
#
# Polymorphism is a concept in object-oriented programming in which a single interface is applicable with different types.
#
# * Often this means similar operations are grouped together with the same name.
# * The operations with the same name will produce different results.

# %%
a = 5
b = 10
print(a + b)

c = '5'
d = '10'
print(c + d)
# Out:
# 15
# 510

# %% [markdown]
# * The plus operator can add together two numbers and concatenate two strings.
# * A single interface (the plus operator) working with different data types (integers and strings).
# * This is an example of polymorphism.

# %%
a = 5
b = '10'
print(a + b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-8cb5bc0ac20e> in <cell line: 3>()
#       1 a = 5
#       2 b = '10'
# ----> 3 print(a + b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# **Why is there an error?**
# * Polymorphism allows Python to use the plus operator with different data types, but that does not mean that the plus operator can be used with all data types.
# * There are limits to polymorphism.

# %% [markdown]
# ### Method Overriding
#
# * Method overriding has a single interface (the method name) and works with different types (the parent and child classes).
# * Overriding a method means that you have two methods with the same name, but they perform different tasks.
# * Again you see a single interface (the method name) being used with different forms (the parent class and the child class)

# %%
class Alpha:
  def show(self):
    print("I am from class Alpha")

class Bravo(Alpha):
  def show(self):
    print("I am from class Bravo")

test_object = Alpha()
test_object.show()
# Out:
# I am from class Alpha

# %%
test_object = Bravo()
test_object.show()
# Out:
# I am from class Bravo

# %% [markdown]
# * The method call did not change, but the output did.
# * A single interface (the .show() method) works with multiple data types (Alpha and Bravo).
# * This is why method overriding is an example of polymorphism.**

# %% [markdown]
# **Create and overload the method hello that prints Hello from Alpha and Hello from Bravo. Test the method with both class types.**

# %%
class Alpha:
  def show(self):
    print("I am from class Alpha")

  def hello(self):
    print("Hello from Alpha")

class Bravo(Alpha):
  def show(self):
    print("I am from class Bravo")

  def hello(self):
    print("Hello from Bravo")

test_object = Alpha()
test_object.hello()
# Out:
# Hello from Alpha

# %%
test_object = Bravo()
test_object.hello()
# Out:
# Hello from Bravo

# %% [markdown]
# ### Method Overloading
# * Method overloading is another example of polymorphism.
# * Method overloading occurs when you have a single method name that can take different sets of parameters.

# %%
class TestClass:
  def sum(self, a, b, c):
    return a + b + c

  def sum(self, a, b):
    return a + b

obj = TestClass()
print(obj.sum(1, 2))
# Out:
# 3

# %% [markdown]
# **Why did Python not determine that this method should be used instead?**
#
# * When two or more methods have the same name, Python only recognizes the last method. All of the others are ignored.
# * That is why you got an error message. Python only recognizes the second sum method.

# %% [markdown]
# Instead, you should create a method with optional parameters. Set the default for each parameter to None.
#
# **By structuring the parameters in this way, you can overload the sum method to work in many different situations. This is how method overloading promotes polymorphism.**

# %%
class TestClass:
  def sum(self, a = None, b = None, c = None):
    if a is not None and b is not None and c is not None:
      return a + b + c
    elif a is not None and b is not None:
      return a + b
    elif a is not None:
      return a
    else:
      return 0

obj = TestClass()
print(obj.sum())
print(obj.sum(1))
print(obj.sum(1, 2))
print(obj.sum(1, 2, 3))
# Out:
# 0
# 1
# 3
# 6

# %% [markdown]
# * Test to see if each parameter is not None. If this is true, the method was passed three parameters, and you return the sum of the three parameters.
# * If the first two parameters are not None then return the sum of the two parameters.
# * If only one parameter is not None then return the parameter. Finally, if all of the parameters are None then return 0.

# %% [markdown]
# **Add on to the sum method such that it can take up to five numbers as parameters. Be sure to test all possible method calls.**
#
# * The compound conditionals have been broken up over several lines to help with legibility.

# %%
class TestClass:
  def sum(self, a = None, b = None, c = None, d = None, e = None):
    if (a is not None and
        b is not None and
        c is not None and
        d is not None and
        e is not None):
      return a + b + c + d + e
    elif (a is not None and
          b is not None and
          c is not None and
          d is not None):
      return a + b + c + d
    elif (a is not None and
          b is not None and
          c is not None):
      return a + b + c
    elif a is not None and b is not None:
      return a + b
    elif a is not None:
      return a
    else:
      return 0

obj = TestClass()
print(obj.sum())
print(obj.sum(1))
print(obj.sum(1, 2))
print(obj.sum(1, 2, 3))
print(obj.sum(1, 2, 3, 4))
print(obj.sum(1, 2, 3, 4, 5))
# Out:
# 0
# 1
# 3
# 6
# 10
# 15

# %%
class TestClass:
  def sum(self, *args):
    total = 0
    for i in args:
      total += i
    return total

# %%
test = TestClass()
test.sum(1, 2, 3, 4, 5, 6, 7, 8)
# Out:
# 36

# %% [markdown]
# #### The None Type
#
# **Why not replace None as the default parameter with 0?**
# * After all, zero represents the lack of a value.

# %%
class TestClass:
  def sum(self, a = 0, b = 0, c = 0):
    if a != 0 and b != 0 and c != 0:
      return a + b + c
    elif a != 0 and b != 0:
      return a + b
    elif a != 0:
      return a
    else:
      return 0

obj = TestClass()
print(obj.sum(0, 2))
# Out:
# 0

# %% [markdown]
# * The answer should be 2. Instead, Python returned 0. This is because zero is not nothing.
# * Zero is an integer. When you want to have a placeholder for the absence of a value, None is the preferable choice.
# * This is a common practice in Python.

# %% [markdown]
# ### Operator Overloading
# * When a single operator can be used with many data types, this is called operator overloading.
# * Operator overloading is another example of polymorphism.
#
# *The plus operator is not the only built-in operator that is overloaded. The multiplication operator can also work with integers and strings.*

# %%
my_string = "polymorphism"
num1 = 3
num2 = 5
print(num1 * num2)
print(my_string * num1)
# Out:
# 15
# polymorphismpolymorphismpolymorphism

# %% [markdown]
# **In Python, everything is an object. So when you write num1 * num2 what you are really saying is that the integer class (int) is calling the multiply method (__mul__), and num1 and num2 are the parameters for this method.**

# %%
num1 = 3
num2 = 5
print(int.__mul__(num1, num2))
# Out:
# 15

# %%
print(int.__add__(num1, num2))
# Out:
# 8

# %%
print(int.__sub__(num1, num2))
# Out:
# -2

# %%
print(int.__truediv__(num1, num2))
# Out:
# 0.6

# %% [markdown]
# #### Operator Overloading and User-Defined Classes
#
# The way how you can overload operators for built-in classes, but you can also overload operators for classes that you create.

# %%
class FinancialAccount:
  def __init__(self, amount):
    self.account = amount

class BankAccount(FinancialAccount):
  pass

class InvestmentAccount(FinancialAccount):
  pass

my_banking = BankAccount(500)
my_investments = InvestmentAccount(750)

# %% [markdown]
# * What we would like to be able to do is say my_banking + my_investments and have Python calculate the sum of the account attributes.
# * We want the plus operator to be overloaded for both BankAccount and InvestmentAccount.
# * Overload the operator in the parent class so that both subclasses inherit this behavior.

# %%
class FinancialAccount:
  def __init__(self, amount):
    self.account = amount

  def __add__(self, other):
    return self.account + other.account

class BankAccount(FinancialAccount):
  pass

class InvestmentAccount(FinancialAccount):
  pass

my_banking = BankAccount(500)
my_investments = InvestmentAccount(750)
print(my_investments + my_banking)
# Out:
# 1250

# %% [markdown]
# Remove the overloaded operator from the FinancialAccount class, and overload the plus operator in the BankAccount class.

# %%
class FinancialAccount:
  def __init__(self, amount):
    self.account = amount

class BankAccount(FinancialAccount):
  def __add__(self, other):
    return self.account + other.account

# %%
fa1 = FinancialAccount(50)
fa1.account
# Out:
# 50

# %%
fa2 = BankAccount(20)
fa2.account
# Out:
# 20

# %%
fa2.__add__(fa1)
# Out:
# 70

# %% [markdown]
# ### Magic Methods
# * All of the methods for operator overloading had leading and trailing double underscores.
# * These methods are called “dunder” methods for short (`__add__` would be pronounced “dunder add”).
# * These methods are also called **magic methods**.

# %% [markdown]
# **Overload the equality operator to check if the the two accounts are equal.**

# %%
class FinancialAccount:
  def __init__(self, amount):
    self.account = amount

  def __eq__(self, other):
    return self.account == other.account

class BankAccount(FinancialAccount):
  pass

class InvestmentAccount(FinancialAccount):
  pass

my_banking = BankAccount(500)
my_investments = InvestmentAccount(750)
print(my_investments == my_banking)
# Out:
# False

# %% [markdown]
# **Overload the division operator so you can divide my_banking by my_investments (or vice versa).**

# %%
class FinancialAccount:
  def __init__(self, amount):
    self.account = amount

  def __truediv__(self, other):
    return self.account / other.account

class BankAccount(FinancialAccount):
  pass

class InvestmentAccount(FinancialAccount):
  pass

my_banking = BankAccount(500)
my_investments = InvestmentAccount(750)
print(my_investments / my_banking)
# Out:
# 1.5

# %% [markdown]
# **Overload the floor division operator (//) to work with my_banking and my_investments.**

# %%
class FinancialAccount:
  def __init__(self, amount):
    self.account = amount

  def __floordiv__(self, other):
    return self.account // other.account

class BankAccount(FinancialAccount):
  pass

class InvestmentAccount(FinancialAccount):
  pass

my_banking = BankAccount(500)
my_investments = InvestmentAccount(750)
print(my_investments // my_banking)
# Out:
# 1

# %% [markdown]
# ### Duck Typing
#
# * Duck typing is used to determine the suitability of an object not based on what it is, but based on what it does.
#
# * The type or class of an object is less important than the methods it defines
#
# * Instead of checking for the class or type, check the object for presence of specific methods and/or attributes
#
# * Duck typing gets its name from the expression, “If it walks like a duck and talks like a duck, then it must be a duck.” We do not care if it really is a duck as long as it acts like a duck.
# * Duck typing is an example of polymorphism because, in this case, a single function works with objects of different types.

# %% [markdown]
# **There are two totally unrelated classes, a baseball player and a song. An instance from each class is passed to the function print_hit which prints the result of the hit method.**

# %%
import random

class BaseballPlayer:
  def hit(self):
    """Generate a random integer 1 to 4 and return the type of hit"""
    total_bases = random.randint(1, 4)
    if total_bases == 1:
      return "single"
    elif total_bases == 2:
      return "double"
    elif total_bases == 3:
      return "triple"
    else:
      return "home run"

class Song:
  def __init__(self, title, ranking):
    self.title = title
    self.ranking = ranking

  def hit(self):
    """A song is a hit if it appeared in a top 40 chart"""
    if self.ranking <= 40:
      return f"{self.title} is a hit song"
    else:
      return f"{self.title} is not a hit song"

def print_hit(obj):
  print(obj.hit())

my_player = BaseballPlayer()
my_song = Song("Hey Jude", 12)

print_hit(my_player)
print_hit(my_song)
# Out:
# triple
# Hey Jude is a hit song

# %% [markdown]
# **The print_hit function does not care if the object is has the type BaseballPlayer or Song. It only cares if the object has a hit method.**

# %% [markdown]
# Add the class Boxer to the class above. This class should have a hit method that returns the string "jab".

# %%
import random

class BaseballPlayer:
  def hit(self):
    """Generate a random integer 1 to 4 and return the type of hit"""
    total_bases = random.randint(1, 4)
    if total_bases == 1:
      return "single"
    elif total_bases == 2:
      return "double"
    elif total_bases == 3:
      return "triple"
    else:
      return "home run"

class Song:
  def __init__(self, title, ranking):
    self.title = title
    self.ranking = ranking

  def hit(self):
    """A song is a hit if it appeared in a top 40 chart"""
    if self.ranking <= 40:
      return f"{self.title} is a hit song"
    else:
      return f"{self.title} is not a hit song"

class Boxer:
  def hit(self):
    return "jab"

def print_hit(obj):
  print(obj.hit())

my_player = BaseballPlayer()
my_song = Song("Hey Jude", 12)

print_hit(my_player)
print_hit(my_song)

my_boxer = Boxer()
print_hit(my_boxer)
# Out:
# home run
# Hey Jude is a hit song
# jab

# %% [markdown]
# #### Handling Errors
# Since print_hit only cares about the hit method, it is possible to send an object to the function that does not have a hit method.

# %%
import random

class BaseballPlayer:
  def hit(self):
    """Generate a random integer 1 to 4 and return the type of hit"""
    total_bases = random.randint(1, 4)
    if total_bases == 1:
      return "single"
    elif total_bases == 2:
      return "double"
    elif total_bases == 3:
      return "triple"
    else:
      return "home run"

class Dancer:
  def pirouette(self):
    return "Spin, spin, spin"

def print_hit(obj):
  print(obj.hit())

my_player = BaseballPlayer()
my_dancer = Dancer()

print_hit(my_player)
print_hit(my_dancer)
# Out:
# double
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-26c0922df5e3> in <cell line: 27>()
#      25
#      26 print_hit(my_player)
# ---> 27 print_hit(my_dancer)
#
# <ipython-input-72-26c0922df5e3> in print_hit(obj)
#      19
#      20 def print_hit(obj):
# ---> 21   print(obj.hit())
#      22
#      23 my_player = BaseballPlayer()
#
# AttributeError: 'Dancer' object has no attribute 'hit'

# %% [markdown]
# * A common response is to check and make sure the object has the proper type before executing the hit method.
# * That would violate the spirit of duck typing.

# %%
def print_hit(obj):
  try:
    print(obj.hit())
  except AttributeError as e:
    print(e)

# %% [markdown]
# ## Abstraction
# * Fundamental problem in computer science: decompose complex problems and systems into smaller units that can be understood in isolation. We use the term "abstraction" to refer to these units.
# * An abstraction is a representation of something independent from its specific details or context, a building’s blueprint would be a good example.
# * The use of abstraction involves removing successive layers of detail from a representation in order to capture only the essential features that are generic to all entities of that kind and independent of their specific form. An architect's master plan of a building is an example of an abstract representation, because it is designed to capture only the most essential features that are required to get an idea.
# * Abstraction involves identifying common attributes to a variety of instances of some entity and the formation of a generic model that captures the fundamental aspects of it without reference to any specific instance or context.
# * Using abstraction we can define different levels to a model depending on its degree of detail or granularity, it is called encapsulation. Encapsulate one model of a system inside another which inturn may be encapsulated within third and so on, creates an heirarchy within representation.
# * Also, there are times when we do not want to give out sensitive parts of our code implementation and this is where data abstraction can also prove to be very functional.
# * The main focus of data abstraction is to separate the interface and the implementation of the program.
#
# **Example**
# * For example, people do not think of a car as a set of thousands of individual parts.
# * Instead they see it as a well-defined object with its own unique behavior.
# * This abstraction allows people to use a car to drive without knowing the complexity of the parts that form the car.
# * They can ignore the details of how the engine transmission, and braking systems work.
# * Instead, they are free to utilize the object as a whole.

# %% [markdown]
# #### Abstract Thinking
# * To think in the abstract is not to see the world in terms of concrete instances but instead to see the categories or general types that a specific instance forms part of.
# > * A concrete thinker can see that a particular house is big; a more abstract thinker can think about the concept of size or scale in general.
# > * A concrete thinker can recognize that Jane is a friend of Kate; a more abstract thinker can reflect on relationships and friendships.
# > * Someone thinking in a concrete form can count five birds; but by thinking in the abstract, one can reason about numbers in general.

# %% [markdown]
# * Abstraction involves the synthesizing of disparate qualities attributes or forms, putting together things that in their concrete form are different.
# * In this sense, the process of abstraction entails the identification of similarities between objects, and associating these objects with an abstraction type.
# * Thus, an abstraction can be seen as a compact representation and in order to create it one must “compress” information into a more condensed form.
# * The final abstraction must contain less information or data than the original set of instances that it is designed to represent.

# %% [markdown]
# * Abstraction is key to dealing with complexity through encapsulation of parts in a hierarchical fashion that give structure and order
# * Abstraction is central to dealing with complexity. Where complexity represents a large number of diverse elements, abstraction can be used to find common attributes and functions that simplify this complexity.

# %% [markdown]
# ### Abstract Method
# * Sometimes, we may not know the implementation details, but we can still declare a method. Such methods are called abstract methods, meaning **they only have a declaration but no implementation**.
#
# * An abstract method is a method that is declared within an abstract class but does not have any implementation. Subclasses are forced to provide a concrete implementation of the abstract method.
# * Purpose: It ensures that subclasses provide specific functionality by implementing thesemethods, enforcing certain behaviors.
#
# * We can declare abstract method by using `@abstractmethod` decorator
# ```
# @abstractmethod
# def method(self):
#   pass
# ```
# * `@abstractmethod` decorator present in abc module. `abc` is abstract base class module

# %%
from abc import ABC, abstractmethod
@abstractmethod
def method(self):
  pass

# %%
# Example
from abc import *
class Fruit:
  @abstractmethod
  def taste(self):
    pass

# %% [markdown]
# **Child classes are responsible to provide implemention for parent class abstract methods.**

# %% [markdown]
# ### Abstract class
# * **A class from which an object cannot be created is called an abstract
# class.**
# * The abstract class is an **interface**. Interfaces in OOP enable a class to inherit data and functions from a base class by extending it.
# * Sometimes, the implementation of a class is not complete. Such partially implemented classes are called abstract classes.
# * An abstract class in Python is a class that contains one or more abstract methods.Abstract methods are methods that are declared, but contain no implementation, and must beimplemented by any concrete (non-abstract) subclass.
# * Purpose: Abstract classes are used to provide a blueprint for other classes. They allow you todefine methods that must be created in any child class but leave the implementation details tothe subclasses
# * In Python, every abstract class must be derived from the ABC class, which is present in the abc module
# * Abstract class just serves as a template for other classes by defining a list of methods that the classes must implement.

# %%
from abc import *
class Test(ABC):
  @abstractmethod
  def m1(self):
    pass

# %%
t=Test()
t.m1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-6f8ec35dfbe1> in <cell line: 1>()
# ----> 1 t=Test()
#       2 t.m1()
#
# TypeError: Can't instantiate abstract class Test with abstract method m1

# %% [markdown]
# * If a class contains atleast one abstract method and if we are extending ABC
# class then instantiation is not possible.
# * **abstract class with abstract method instantiation is not possible**

# %% [markdown]
# **Abstract methods in a parent class must be implemented in the child classes; otherwise, we cannot instantiate the child class. However, if we do not create an object of the child class, no error will occur.**

# %%
from abc import *
class Vehicle(ABC):
  @abstractmethod
  def noofwheels(self):
    pass

class Bus(Vehicle):
  pass

# %%
b = Bus()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-211240138a71> in <cell line: 1>()
# ----> 1 b = Bus()
#
# TypeError: Can't instantiate abstract class Bus with abstract method noofwheels

# %% [markdown]
# **If we are extending abstract class and does not override its abstract method then child class is also abstract and instantiation is not possible.**

# %% [markdown]
# #### Partial Abstraction
#
# * Abstract classes in Python can also have concrete methods in addition to abstractmethods. This is called partial abstraction, where some methods are implemented, and othersare left for the subclass to implement.
#
# * This allows the abstract class to provide a default behavior while still enforcing certain methods to be overridden

# %%
from abc import ABC, abstractmethod

class vehicle(ABC):
    @abstractmethod
    def getNoOfWheels(self):
        pass

class bus(vehicle):
    def getNoOfWheels(self):
        return 6

class auto(vehicle):
    def getNoOfWheels(self):
        return 3

b = bus()
a = auto()
b.getNoOfWheels(), a.getNoOfWheels()
# Out:
# (6, 3)

# %% [markdown]
# #### Interfaces (Using Abstraction)
# * An interface is a fully abstract class in Python where all methods are abstract andmust be implemented by the subclass. Python doesn’t have interfaces as a separate concept like Java, but abstract classes with all methods abstract can act as interfaces
# * This enforces that the subclass implements every method of the abstract class,ensuring a particular structure.
#
# **If an abstract class contains only methods marked by the decorator
# @abstractmethod, it is often called an interface.**

# %%
from abc import ABC, abstractmethod
class collegeAutomation(ABC):
    @abstractmethod
    def m1(self):
        pass
    @abstractmethod
    def m2(self):
        pass
    @abstractmethod
    def m3(self):
        pass

class Impl(collegeAutomation):
    def m1(self):
        print("m1 method")
    def m2(self):
        print("m2 method")
    def m3(self):
        print("m3 method")

i = Impl()
i.m1()
i.m2()
i.m3()
# Out:
# m1 method
# m2 method
# m3 method

# %% [markdown]
# #### Conclusions
# * If a class contains atleast one abstract method and if we are extending ABC class then instantiation is not possible. **"For abstract class with abstract method instantiation is not possible"**
# * Parent class abstract methods should be implemented in the child classes. Otherwise we
# cannot instantiate child class.If we are not creating child class object then we won't get
# any error.
# *  If we are creating child class for abstract class then for every abstract method of parent class compulsory we should provide implementation in the child class, otherwise child class is also abstract and we cannot create object for child class.

# %% [markdown]
# #### Encapsulation and Abstraction
#
# * Abstraction and Encapsulation are closely related but distinct concepts.
# * **Encapsulation:** Refers to the bundling of data and methods that operate on the data,restricting direct access to some of the object’s components (private/protected members).
# * **Abstraction:** Focuses on hiding the complexity of implementation and exposing only thenecessary parts
# * **Example:** Encapsulation involves controlling access to certain components, while abstraction hides the complexities by only exposing relevant methods to the user.
