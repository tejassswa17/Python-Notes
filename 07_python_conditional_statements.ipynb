# %% [markdown]
# ## Conditional Statements
#
# Sequence of execution of instructions in a program can be altered using:
# * Decision control instruction (Conditional Statements)
# * Repetition control instruction (Loops)

# %% [markdown]
# ### Recap: Comparision Operators

# %% [markdown]
# #### What Is True?
#
# **What if the element we’re checking isn’t a boolean? What does Python consider True and False?**
#
# A false value doesn’t necessarily need to explicitly be a boolean False. For example, these are all considered False.
#
# - boolean `False`
# - null `None`
# - zero integer `0`
# - zero float `0.0`
# - empty string `''`
# - empty list `[ ]`
# - empty tuple `( )`
# - empty dict `{ }`
# - empty set `set( )`

# %%
bool(False)
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %%
bool('')
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool(())
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
bool(set())
# Out:
# False

# %% [markdown]
# Anything else is considered True. Python programs use these definitions of “truthiness” and “falsiness” to check for empty data structures as well as False conditions

# %% [markdown]
# ### Conditional Statements
#
# * The kinds of computations we have been looking at thus far are called straightline programs. They execute one statement after another in the order in which they appear, and stop when they run out of statements
# * Branching programs are more interesting. The simplest branching statement is
# a conditional.
# * A conditional statement has three parts:
# > - a test, i.e., an expression that evaluates to either True or False;
# > - a block of code that is executed if the test evaluates to True; and
# > - an optional block of code that is executed if the test evaluates to False.
#
# After a conditional statement is executed, execution resumes at the code
# following the statement.
#
# In Python, a conditional statement has the form
#
# ```
# if <boolean expression>:
#     block of code
# else:
#     block of code
# ```

# %% [markdown]
# **In the conditional statements the simplest form is the if statement**
# * The boolean expression after the if statement is called the condition.
# * We end the if statement with a colon character (:) and the line(s) after the if statement are indented.
# * If the logical condition is true, then the indented statement gets executed. If the logical condition is false, the indented statement is skipped.
# * There is no limit on the number of statements that can appear in the body, but
# there must be at least one.

# %%
x = int(input('Enter a number: '))
if x > 0 :
  print(f'{x} is a positive number')
# Out:
# Enter a number: 90
# 90 is a positive number

# %% [markdown]
# **Occasionally, it is useful to have a body with no statements (usually as a place holder for code you haven’t written yet). In that case, you can use the pass statement, which does nothing.**
#
# The `pass` statement serves as a placeholder where a statement is needed, but it performs no action.
#
# `pass` statement is intended to do nothing on execution. Hence it is
# often called a no-op instruction.

# %%
if x < 0:
  pass

# %% [markdown]
# **Indentation is semantically meaningful in Python**
#
# For example, if the last statement in the code is indented it would be part of the block of code associated with the if, rather than with the block of code following the conditional statement.

# %%
i = 5 # unindented line, starting from the beggining of the code cell

if(i < 10): # if block header: 'if' keyword - (condition that evaluates to a boolean value) - ends with ':'
    print('Inside the IF block')
    print(i)

print('This is outside the IF block')
# Out:
# Inside the IF block
# 5
# This is outside the IF block

# %%
i = 15 # unindented line, starting from the beggining of the code cell

if(i < 10): # if block header: 'if' keyword - (condition that evaluates to a boolean value) - ends with ':'
    print('Inside the IF block')
    print(i)

print('This is outside the IF block')
# Out:
# This is outside the IF block

# %% [markdown]
# **Consider the following program that prints “Even” if the value of the variable x is even and “Odd” otherwise:**

# %%
x = int(input('Enter a number to check whether given number is even or odd:'))

if x%2 == 0:
  print(f'{x} is Even')
if x%2 != 0:
  print(f'{x} is Odd')
# Out:
# Enter a number to check whether given number is even or odd:5
# 5 is Odd

# %% [markdown]
# **The if statement can have zero or more elif statements,
# but they can only have up to one else statements**

# %%
x = int(input('Enter a number to check whether given number is even or odd:'))
if x%2 == 0:
  print(f'{x} is Even')
else:
  print(f'{x} is Odd')
print('Done with conditional')
# Out:
# Enter a number to check whether given number is even or odd:5
# Odd
# Done with conditional

# %% [markdown]
# #### Question:Write a Program(WAP) to find the relationship between two variables and prints the output.

# %%
x = int(input('Enter the value of x: '))
y = int(input('Enter the value of y: '))

if x > y:
  print(f'{x} is greater than {y}')
if x < y:
  print(f'{x} is less than {y}')
# Out:
# Enter the value of x: 2
# Enter the value of y: 3
# 2 is less than 3

# %%
x = int(input('Enter the value of x: '))
y = int(input('Enter the value of y: '))

if x > y:
  print(f'{x} is greater than {y}')
else:
  print(f'{x} is less than {y}')
# Out:
# Enter the value of x: 2
# Enter the value of y: 3
# 2 is less than 3

# %% [markdown]
# #### Nested conditionals
#
# One conditional can also be nested within another. We could have written the
# three-branch example like this

# %%
 x = int(input('Enter the value of x: '))
y = int(input('Enter the value of y: '))

if x == y:
  print('x and y are equal')
else:
  if x < y:
    print('x is less than y')
  else:
    print('x is greater than y')
# Out:
# Enter the value of x: 5
# Enter the value of y: 7
# x is less than y

# %% [markdown]
# Although the indentation of the statements makes the structure apparent, nested
# conditionals become difficult to read very quickly. In general, it is a good idea to avoid them when you can.

# %%
x = int(input('Enter the value of x: '))
y = int(input('Enter the value of y: '))

if x >= y:
  if x == y:
    print('x and y are equal')
  else:
    print('x is greater than y')
else:
  print('x is less than y')
# Out:
# Enter the value of x: 7
# Enter the value of y: 7
# x and y are equal

# %%
x = int(input('Enter the value of x: '))
y = int(input('Enter the value of y: '))

if x > y:
  print('x is greater than y')
else:
  if x == y:
    print('x and y are equal')
  else:
    print('x is less than y')
# Out:
# Enter the value of x: 7
# Enter the value of y: 5
# x is greater than y

# %%
x = int(input('Enter the value of x: '))
y = int(input('Enter the value of y: '))

if x <= y:
  if x == y:
    print('x and y are equal')
  else:
    print('x is less than y')
else:
  print('x is greater than y')
# Out:
# Enter the value of x: 7
# Enter the value of y: 5
# x is greater than y

# %%
x = int(input('Enter the value of x: '))
y = int(input('Enter the value of y: '))

if x < y:
  print('x is less than y')
else:
  if x == y:
    print('x and y are equal')
  else:
    print('x is greater than y')
# Out:
# Enter the value of x: 7
# Enter the value of y: 5
# x is greater than y

# %% [markdown]
# #### Chained conditionals
# **Sometimes there are more than two possibilities and we need more than two
# branches. One way to express a computation like that is a chained conditional**
#
# elif is an abbreviation of “else if.”

# %%
x = int(input('Enter the value of x: '))
y = int(input('Enter the value of y: '))

if x < y:
  print('x is less than y')
elif x > y:
  print('x is greater than y')
else:
  print('x and y are equal')
# Out:
# Enter the value of x: 5
# Enter the value of y: 7
# x is less than y

# %%
x = int(input('Enter the value of x: '))
y = int(input('Enter the value of y: '))

if x > y:
  print('x is greater than y')
elif x < y:
  print('x is less than y')
else:
  print('x and y are equal')
# Out:
# Enter the value of x: 7
# Enter the value of y: 7
# x and y are equal

# %% [markdown]
# **There is no limit on the number of elif statements. If there is an else clause, it has to be at the end, but there doesn’t have to be one.**
#
# The elif keyword is used to check for those conditions which weren't done so by the previous statements. As a rule of thumb, if we're checking for n number of outcomes(n > 2), we'll be having n-2 number of elif statements

# %%
choice = input('Choose an option among a/b/c: ')
if choice == 'a':
  print('Bad guess')
elif choice == 'b':
  print('Good guess')
elif choice == 'c':
  print('Close, but not correct')
# Out:
# Choose an option among a/b/c: a
# Bad guess

# %% [markdown]
# #### Question: WAP for passing the exam if the students meets the cutoff(35)

# %%
cutoffscore = 35
marksscored = input('Enter the Marks:')

if(int(marksscored) >= cutoffscore):
  print('Result: Pass')
# Out:
# Enter the Marks:45
# Result: Pass

# %%
cutoffscore = 35
marksscored = int(input('Enter the Marks:'))

if(marksscored >= cutoffscore):
  print('Result: Pass')
# Out:
# Enter the Marks:25

# %%
cutoffscore = 35
marksscored = int(input('Enter the Marks:'))

if(marksscored >= cutoffscore):
  print('Result: Pass')
if(marksscored < cutoffscore):
  print('Result: Fail')
# Out:
# Enter the Marks:25
# Result: Fail

# %%
cutoffscore = 35
marksscored = int(input('Enter the Marks:'))

if(marksscored >= cutoffscore):
  print('Result: Pass')
else:
  print('Result: Fail')
# Out:
# Enter the Marks:125
# Result: Pass

# %% [markdown]
# **What happens when a user enter marks GREATER THAN 100?**
# - We need to address this exception

# %%
cutoffscore = 35
marksscored = int(input('Enter the Marks:'))
if marksscored <= 100:
  if(marksscored >= cutoffscore):
    print('Result: Pass')
  else:
    print('Result: Fail')
# Out:
# Enter the Marks:100
# Result: Pass

# %%
cutoffscore = 35
marksscored = int(input('Enter the Marks:'))
if marksscored <= 100:
  if(marksscored >= cutoffscore):
    print('Result: Pass')
  else:
    print('Result: Fail')
else:
  print('Exam is conducted for 100 marks, max marks you can score 100')
# Out:
# Enter the Marks:100
# Result: Pass

# %%
cutoffscore = 35
marksscored = int(input('Enter the Marks:'))
if marksscored > 100:
  print('Exam is conducted for 100 marks, max marks you can score 100')
elif marksscored >= cutoffscore:
  print('Result: Pass')
else:
  print('Result: Fail')
# Out:
# Enter the Marks:65
# Result: Pass

# %% [markdown]
# **Along with pass an fail add the distinction condition to program**

# %%
cutoffscore = 35
distinctioncutoff = 75
marksscored = int(input('Enter the Marks:'))

if marksscored > 100:
  print('Exam is conducted for 100 marks, max marks you can score 100')
elif marksscored >= 75:
  print('Result: Pass with Distinction')
elif marksscored >= 35:
  print('Result: Pass')
else:
  print('Result: Fail')
# Out:
# Enter the Marks:80
# Result: Pass with Distinction

# %% [markdown]
# #### Question: WAP to calculate income tax based on the given taxable percentage ranges

# %% [markdown]
# ##### Using nested conditionals

# %%
taxable_income = float(input('Enter the taxable income in LPA:'))

# taxable_income = taxable_income/100000

# 0 - 2.5 - 0%
# 2.5 - 5 - 5%
# 5. - 10 - 20%
# 10 or above - 30%

if(taxable_income>=10):
    print('Slab is{} and Tax Payable is {}'.format('30%',taxable_income*0.3))
else:
    if(taxable_income<10 and taxable_income>=5):
        print('Slab is {} and Tax Payable is {}'.format('20%',taxable_income*0.2))
    else:
        if(taxable_income<5 and taxable_income>=2.5):
            print('Slab is {} and Tax Payable is {}'.format('5%',taxable_income*0.05))
        else:
            print('Slab is {} and Tax Payable is {}'.format('0%',0))
# Out:
# Enter the taxable income in LPA:10
# Slab is30% and Tax Payable is 3.0

# %% [markdown]
# ##### Using chained conditionals

# %%
taxable_income = float(input('Enter the taxable income:'))

# taxable_income = taxable_income/100000

# 0 - 2.5 - 0%
# 2.5 - 5 - 5%
# 5. - 10 - 20%
# 10 or above - 30%

if(taxable_income>=10):
    print('Slab is {} and Tax Payable is {}'.format('30%',taxable_income*0.3))
elif(taxable_income<10 and taxable_income>=5):
    print('Slab is {} and Tax Payable is {}'.format('20%',taxable_income*0.2))
elif(taxable_income<5 and taxable_income>=2.5):
    print('Slab is {} and Tax Payable is {}'.format('5%',taxable_income*0.05))
else:
    print('Slab is {} and Tax Payable is {}'.format('0%',0))
# Out:
# Enter the taxable income:10
# Slab is 30% and Tax Payable is 3.0

# %% [markdown]
# #### Write a program which will accept a word from the user and check whether the word starts with a vowel or not

# %%
# taking the input
word = input('Enter the word you want to check: ')

# creating a vowel list to refer to when checking
vowels = ['a','e','i','o','u']

# checking the condition
if word[0].lower() in vowels:
    print(f'The word, {word.capitalize()}, starts with a vowel')
else:
    print("The word, {word.capitalize()}, doesn't start with a vowel")
# Out:
# Enter the word you want to check: Innomatics
# The word, Innomatics, starts with a vowel

# %% [markdown]
# #### Write a program to determine whether the year is a leap year or not.
#
# The logic for determining leap years is as follows:
#
# 1. If a year is evenly divisible by 4, it is a leap year.
# 2. However, if the year is evenly divisible by 100, it is not a leap year, unless:
# 3. The year is also evenly divisible by 400, in which case it is a leap year.

# %%
# Determine whether year is leap or not

year = int(input('Enter a year: '))
if year % 4 == 0 :
  if year % 100 == 0 :
    if year % 400 == 0 :
      print(year, 'is a Leap Year')
    else :
      print(year, 'is not a Leap Year')
  else :
    print(year, 'is a Leap Year')
else :
  print(year, 'is not a Leap Year')
# Out:
# Enter a year: 1900
# 1900 is not a Leap Year

# %%
year = int(input('Enter a year: '))

if year % 400 == 0:
  print(year, 'is a Leap Year')
elif year % 100 == 0:
  print(year, 'is not a Leap Year')
elif year % 4 == 0:
  print(year, 'is a Leap Year')
else:
  print(year, 'is not a Leap Year')
# Out:
# Enter a year: 1900
# 1900 is not a Leap Year

# %%
year = int(input('Enter a year: '))

if year%100 == 0:
  if year%400 == 0:
    print(year, 'is a Leap Year')
  else:
    print(year, 'is not a Leap Year')
else:
  if year%4 == 0:
    print(year, 'is a Leap Year')
  else:
    print(year, 'is not a Leap Year')
# Out:
# Enter a year: 2024
# 2024 is a Leap Year

# %%
year = int(input('Enter a year: '))

if year%400 == 0:
  print(year, 'is a Leap Year')
else:
  if year%4 and year%100 != 0:
    print(year, 'is a Leap Year')
  else:
    print(year, 'is not a Leap Year')
# Out:
# Enter a year: 2000
# 2000 is a Leap Year

# %%
year = int(input('Enter a year: '))

if year % 4 == 0 and year % 100 != 0:
  print(f'{year} is a leap year')
elif year % 400 == 0:
  print(f'{year} is a leap year')
else:
  print(f'{year} is not a leap year')
# Out:
# Enter a year: 2024
# 2024 is a leap year

# %%
True and True or True
# Out:
# True

# %%
True and True or False
# Out:
# True

# %%
# and has more precedence than or
False and True or True
# Out:
# True

# %%
year = int(input('Enter a year: '))

if year%4 == 0 and year%100 !=0 or year%400 == 0:
  print(f'{year} is a leap year')
else:
  print(f'{year} is not a leap year')
# Out:
# Enter a year: 2024
# 2024 is a leap year

# %%
import calendar

year = int(input('Enter a year: '))

if calendar.isleap(year):
  print(f'{year} is a leap year.')
else:
  print(f'{year} is not a leap year.')
# Out:
# Enter a year: 2000
# 2000 is a leap year.

# %% [markdown]
# #### WAP to check whether a triangle is valid or not, when the three angles of the triangle are entered through the keyboard

# %%
# Determine whether triangle is valid or not
x = int(input('Enter angle between sides AB and BC: '))
y = int(input('Enter angle between sides BC and CA: '))
z = int(input('Enter angle between sides CA and AB: '))

sum_of_angles = x + y + z

if sum_of_angles == 180 :
  print('Valid Triangle')
else :
  print('Is not a Valid Triangle')
# Out:
# Enter angle between sides AB and BC: 25
# Enter angle between sides BC and CA: 45
# Enter angle between sides CA and AB: 110
# Valid Triangle
