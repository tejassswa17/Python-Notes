# %% [markdown]
# ## File Handling

# %% [markdown]
# * Data used in a program is temporary; unless the data is specifically saved, it is lost when the program terminates.
# * To permanently store the data created in a program, you need to save it in a file on a disk or some other permanent storage device.
# * The file can be transported and can be read later by other programs.
# * Files can be classified into text or binary files. A file that can be processed (that is, read, created, or modified) using a text editor such as Notepad on Windows or vi on UNIX is called a text file.
# * All the other files are called binary files. For example, Python source programs are stored in text files and can be processed by a text editor, but Microsoft Word files are stored in binary files and are processed by the Microsoft Word program.
# * Computers do not differentiate between binary files and text files. All files are stored in binary format, and thus all files are essentially binary files. Text IO (input and output) is built upon binary IO to provide a level of abstraction for character encoding and decoding.
# * In Python, files are accessed using the file objects. As a matter of fact, the file objects help us to access not just normal disk files but can help us to accomplish many other tasks involving other kinds of files

# %% [markdown]
# ### File IO Basics
# * Open a file
# > * Specify what file you want
# > * Whether to read or write it
# * Read/write from/to the file
# * Close the file
#
# **In python, we arrange for the file to be closed when we open it**

# %% [markdown]
# ### Open a file
# * The first step is to open the desired file, means navigating the file system to find the file in question.
# * The open command requires the **location (path) of the file** and **the filename**.
# ```
# output_file = open('/content/practice1.txt', 'w')
# ```
# * The file is called practice1.txt. It is located in the folder named content. So the path to the file is `/content/practice1.txt`.
# * There are three different modes when opening a file: read ("r"), write ("w"), and append ("a").

# %% [markdown]
# #### File Opening Modes
# There are multiple file-opening modes available:
#
# * 'r' - Opens file for reading in text mode.
# * 'w' - Opens file for writing in text mode.
# * 'a' - Opens file for appending in text mode.
# * 'r+' - Opens file for reading and writing in text mode.
# * 'w+' - Opens file for writing and reading in text mode.
# * 'a+' - Opens file for appending and reading in text mode
# * 'rb' - Opens file for reading in binary mode.
# * 'wb' - Opens file for writing in binary mode.
# * 'ab' - Opens file for appending in binary mode.
# * 'rb+' - Opens file for reading and writing in binary mode.
# * 'wb+' - Opens file for writing and reading in binary mode.
# * 'ab+' - Opens file for appending and reading in binary mode.
#
# If mode argument is not mentioned while opening a file, then 'r' is assumed.

# %% [markdown]
# #### `os` module
# * Importing the os Python module allows Python to interact with the operating system.
# * os can also join the file path and filename together, allowing you to open the file.

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
output_file = open("/content/practice1.txt", "w")
output_file.close()

# %%
read_file =  open('/content/practice1.txt', 'r')
print(read_file.read())
read_file.close()

# %% [markdown]
# **What happens when Python tries to open a file in write mode, but the file does not exist?**
#
# When Python tries to open a nonexistent file in write mode, the file will be created.

# %% [markdown]
# ### Writing to a File
# * Once the file is opened, the `writelines()` method is used to write text to the file.
# * Any string of text passed to writelines() will appear in the file. Once you are done writing to the file, **close the file**.
# ```
# f = open("test.txt",encoding = 'utf-8') ... f.close()
# ```

# %%
output_file = open("/content/practice1.txt", "w")
output_file.write("Hello there")
output_file.close()

# %%
read_file =  open("/content/practice1.txt", "r")
print(read_file.read())
read_file.close()
# Out:
# Hello there

# %%
output_file = open("/content/practice1.txt", "w")
output_file.writelines("Hello there ")
output_file.close()

# %%
read_file =  open('/content/practice1.txt', 'r')
print(read_file.read())
read_file.close()
# Out:
# Hello there

# %% [markdown]
# * When writing to text files, Python outputs raw text.
# * Raw text is the text that appears in a text editor.
# * There is no special formatting or extra information attached to this text. Raw text files have the extension .txt.

# %% [markdown]
# **When we are done with operations to the file, we need to properly close the file. Closing a file will free up the resources that were tied with the file and is done using Python close() method.**
#
# The above method is not entirely safe. If an exception occurs when we are performing some operation with the file, the code exits without closing the file.A safer way is to use a try...finally block.
# ````
# try: f = open("test.txt",encoding = 'utf-8') ... finally: f.close()
# ````

# %%
try:
  output_file = open("/content/practice1.txt", "w")
  output_file.write("Hello there")
finally:
  output_file.close()

# %%
try:
  output_file = open("/content/practice1.txt", "w")
  output_file.writelines("Hello there")
finally:
  output_file.close()

# %% [markdown]
# **Change the string in writelines() to "Goodbye"?**

# %%
output_file = open("/content/practice1.txt", "w")
output_file.writelines("Goodbye")
output_file.close()

# %% [markdown]
# **Change the string in writelines() to ""?**

# %%
output_file = open("/content/practice1.txt", "w")
output_file.writelines("")
output_file.close()

# %% [markdown]
# **Change the mode to open("/content/practice1.txt", "r")?**

# %%
output_file = open("/content/practice1.txt", "r")
output_file.writelines("")
output_file.close()

# %% [markdown]
# #### Testing file existence
#
# * To prevent the data in an existing file from being erased by accident, you should test to see if the file exists before opening it for writing.
# * The isfile function in the os.path module canbe used to determine whether a file exists.

# %%
import os.path
if os.path.isfile("/content/practice1.txt"):
    print("practice1.txt exists")
# Out:
# practice1.txt exists

# %% [markdown]
# #### Multiline Strings
#
# * Imagine that you want to write the words Hello and there on separate lines of a file called practice2.txt.
# * If the print statement writes each string on its own line, then writelines should too.

# %%
output_file = open("/content/practice1.txt", "w")
output_file.write("Hello")
output_file.write("there")
output_file.close()

# %%
output_file = open("/content/practice1.txt", "w")
output_file.writelines("Hello")
output_file.writelines("there")
output_file.close()

# %% [markdown]
# * Closing the file is an important step in working with files. If you forget to close a file, some unpredictable actions may take place.
# * For example, if you open a file with newly written text before closing the file, that text may not be in the file. Be sure that you close all of the files that you open.

# %% [markdown]
# **If you want to have text appear on a new line, then you need to use the newline character (\n).**
#
# Change the writelines() code to:

# %%
output_file = open("/content/practice1.txt", "w")
output_file.write("Hello\n")
output_file.write("there")
output_file.close()

# %%
output_file = open("/content/practice1.txt", "w")
output_file.writelines("Hello\n")
output_file.writelines("there")
output_file.close()

# %% [markdown]
# Change the writelines() code to:

# %%
output_file = open("/content/practice1.txt", "w")
output_file.write("Hello\nthere")
output_file.close()

# %%
output_file = open("/content/practice1.txt", "w")
output_file.writelines("Hello\nthere")
output_file.close()

# %% [markdown]
# #### A List of Strings
#
# * It is possible to use a list of strings with the writelines() method.
# * However, these strings will be written one after another with no space between.
# * If you want spaces, be sure to add them. If you want text to appear on a newline, use \n.

# %%
lines_to_write = ["First sentence.", "Second sentence.", "Third sentence."]
output_file = open("/content/practice2.txt", "w")
output_file.write(lines_to_write)
output_file.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-17-1229358665.py in <cell line: 0>()
#       1 lines_to_write = ["First sentence.", "Second sentence.", "Third sentence."]
#       2 output_file = open("/content/practice2.txt", "w")
# ----> 3 output_file.write(lines_to_write)
#       4 output_file.close()
#
# TypeError: write() argument must be str, not list

# %% [markdown]
# **write vs writelines**
# * In the code above the write method is being used to write text to a file.
# * writelines can accept a single string or a list of strings but write, however, can only accept a single string.

# %%
lines_to_write = ["First sentence.", "Second sentence.", "Third sentence."]
output_file = open("/content/practice2.txt", "w")
output_file.writelines(lines_to_write)
output_file.close()

# %% [markdown]
# **Change lines_to_write to: ["First sentence. ", "Second sentence. ", "Third sentence."]**

# %%
lines_to_write = ["First sentence. ", "Second sentence. ", "Third sentence."]
output_file = open("/content/practice2.txt", "w")
output_file.writelines(lines_to_write)
output_file.close()

# %% [markdown]
# **Change lines_to_write to:
# ["First sentence.\n", "Second sentence.\n", "Third sentence.\n"]**

# %%
lines_to_write = ["First sentence.\n", "Second sentence.\n", "Third sentence.\n"]
output_file = open("/content/practice2.txt", "w")
output_file.writelines(lines_to_write)
output_file.close()

# %% [markdown]
# #### Append Mode
# * Write mode has some unusual behavior. Writing to a non-existent file creates the file.
# * Writing to an **already existing file erases the previous contents of the file**.
# * The append mode will also create a file if one does not already exist. However, append mode will not erase content already saved to the file. It will add the text to the end of the file.

# %%
output_file = open("/content/practice3.txt", "w")
output_file.writelines("First sentence")
output_file.close()

# %%
output_file = open("/content/practice3.txt", "a")
output_file.writelines("Second sentence")
output_file.close()

# %% [markdown]
# **Change the append text to writelines("\nSecond sentence")?**

# %%
output_file = open("/content/practice3.txt", "a")
output_file.writelines("\nSecond sentence")
output_file.close()

# %%
new_text = ["How many boards\n", "Could the Mongols hoard\n", "If the Mongols hordes got bored?"]

output_file = open("/content/practice3.txt", "a")
output_file.writelines(new_text)
output_file.close()

# %% [markdown]
# #### With Open
#
# * Opening and closing files is an important part of working with files, but it can be tedious to perform both steps.
# * The **with open** command combines the two lines of code. Once the end of the indented code is reached, the file is automatically closed.

# %%
with open("/content/practice3.txt", "a") as output_file:
  output_file.writelines("Some new text!")

# %% [markdown]
# **Change the text in writelines() to "\nSome new text!"?**

# %%
with open("/content/practice3.txt", "a") as output_file:
    output_file.writelines("\nSome new text!")
    output_file.writelines("\nAnd some more text!")
    output_file.writelines("\nYet even more text!")

# %% [markdown]
# * The **append mode** will add new text to a file without erasing its contents.
# * The **write mode** will overwrite the file with new text.

# %% [markdown]
# **Q1. Write a program that writes the following information to the file tongue_twister.txt.**
#
# **Text:** Peter Piper picked a peck of pickled peppers
#
# A peck of pickled peppers Peter Piper picked
#
# If Peter Piper picked a peck of pickled peppers
#
# Where’s the peck of pickled peppers Peter Piper picked?

# %%
with open('/content/tongue_twister.txt', 'w') as output_file:
  output_file.writelines('Peter Piper picked a peck of pickled peppers\n')
  output_file.writelines('A peck of pickled peppers Peter Piper picked\n')
  output_file.writelines('If Peter Piper picked a peck of pickled peppers\n')
  output_file.writelines('Where’s the peck of pickled peppers Peter Piper picked?')

# %% [markdown]
# **Q2. Assume there is a text file named hand_grenade.txt. Write a program that will add the following text to the file. Your program should not alter any information already in the text file.**
#
# **Text**: And Saint Attila raised the hand grenade up on high, saying,
#
# "O Lord, bless this Thy hand grenade that, with it,
#
# Thou mayest blow Thine enemies to tiny bits in Thy mercy."

# %%
with open('/content/hand_grenade.txt', 'a') as output_file:
  output_file.writelines('And Saint Attila raised the hand grenade up on high, saying,\n')
  output_file.writelines('"O Lord, bless this Thy hand grenade that, with it,\n')
  output_file.writelines('Thou mayest blow Thine enemies to tiny bits in Thy mercy."\n')

# %% [markdown]
# ### Reading a File
#
# Both write and append modes will create a file if it does not already exist. Read mode will cause an error if the file does not already exist.

# %% [markdown]
# #### Reading a Non-Existing File
#
# * Read mode works much like write or append mode. Use a "r" when opening a file.
# * Notice, there no file named read_practice.txt. See if a new file will be created like with the write and append modes.

# %%
read_file = open("/content/read_practice.txt", "r")
read_file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-29-295472483.py in <cell line: 0>()
# ----> 1 read_file = open("/content/read_practice.txt", "r")
#       2 read_file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/read_practice.txt'

# %% [markdown]
# Read mode does not create a new file if the file does not exist. You can only read previously existing files.

# %%
try:
    read_file = open("/content/read_practice.txt", "r")
except FileNotFoundError:
    print("There is no such file exists")
finally:
    read_file.close()
# Out:
# There is no such file exists
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-30-521854487.py in <cell line: 0>()
#       4     print("There is no such file exists")
#       5 finally:
# ----> 6     read_file.close()
#
# NameError: name 'read_file' is not defined

# %% [markdown]
# Use a print statement to print the contents of the file to the screen.

# %%
read_file =  open('/content/practice1.txt', 'r')
print(read_file)
read_file.close()
# Out:
# <_io.TextIOWrapper name='/content/practice1.txt' mode='r' encoding='utf-8'>

# %% [markdown]
# * Python does not print the contents of the text file.
# * Instead it prints information about the file object (name, mode, and encoding).
# * If you want to print the contents of a text file, use the **readlines method**.
# ```
# data = f.read( ) # reads entire file contents and returns as string
# data = f.read(n) # reads n characters, and returns asstring
# data = f.readline( ) # reads a line, and returns asstring
# data = f.readlines( ) # read all the lines in a file and form a list of lines
# ```

# %%
read_file = open('/content/practice1.txt', 'r')
print(read_file.read())
read_file.close()
# Out:
# Hello
# there

# %%
read_file = open('/content/practice1.txt', 'r')
print(read_file.read(2))
read_file.close()
# Out:
# He

# %%
read_file = open('/content/practice1.txt', 'r')
print(read_file.read(8))
read_file.close()
# Out:
# Hello
# th

# %%
read_file = open('/content/practice1.txt', 'r')
print(read_file.readline())
read_file.close()
# Out:
# Hello

# %%
read_file = open('/content/practice1.txt', 'r')
print(read_file.readlines())
read_file.close()
# Out:
# ['Hello\n', 'there']

# %% [markdown]
# Notice how the text is a list of strings, and the newline character (\n) is a part of the output.

# %% [markdown]
# #### File attributes

# %%
read_file.name
# Out:
# '/content/practice1.txt'

# %%
read_file.readable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-38-413320380.py in <cell line: 0>()
# ----> 1 read_file.readable()
#
# ValueError: I/O operation on closed file

# %%
read_file.writable()
# Out:
# False

# %%
read_file.mode
# Out:
# 'r'

# %%
read_file.closed
# Out:
# True

# %% [markdown]
# #### File Iteration - For Loop
# * The readlines method returns all of the text at once. A loop allows you to deal with each line individually.
# * To print out the text as it would normally appear, use a for loop to print each line of the text.

# %%
read_file = open('/content/practice1.txt', 'r')
for line in read_file:
  print(line)
read_file.close()
# Out:
# Hello
#
# there

# %%
read_file = open('/content/practice1.txt', 'r')
print(type(read_file))
print(hasattr(read_file, '__iter__'))
read_file.close()
# Out:
# <class '_io.TextIOWrapper'>
# True

# %%
with open("/content/practice3.txt", "r") as read_file:
    for line in read_file:
      print(line)
# Out:
# First sentenceSecond sentence
#
# Second sentenceHow many boards
#
# Could the Mongols hoard
#
# If the Mongols hordes got bored?Some new text!
#
# Some new text!
#
# And some more text!
#
# Yet even more text!

# %%
with open("/content/practice3.txt", "r") as read_file:
    for line in read_file:
      print(line, end = '')
# Out:
# First sentenceSecond sentence
# Second sentenceHow many boards
# Could the Mongols hoard
# If the Mongols hordes got bored?Some new text!
# Some new text!
# And some more text!
# Yet even more text!

# %%
with open("/content/practice3.txt", "r") as read_file:
    for line in read_file.read():
      print(line)
# Out:
# F
# i
# r
# s
# t
#
# s
# e
# n
# t
# e
# n
# c
# e
# S
# e
# c
# o
# n
# d
#
# s
# e
# n
# t
# e
# n
# c
# e
#
#
# S
# e
# c
# o
# n
# d
#
# s
# e
# n
# t
# e
# n
# c
# e
# H
# o
# w
#
# m
# a
# n
# y
#
# b
# o
# a
# r
# d
# s
#
#
# C
# o
# u
# l
# d
#
# t
# h
# e
#
# M
# o
# n
# g
# o
# l
# s
#
# h
# o
# a
# r
# d
#
#
# I
# f
#
# t
# h
# e
#
# M
# o
# n
# g
# o
# l
# s
#
# h
# o
# r
# d
# e
# s
#
# g
# o
# t
#
# b
# o
# r
# e
# d
# ?
# S
# o
# m
# e
#
# n
# e
# w
#
# t
# e
# x
# t
# !
#
#
# S
# o
# m
# e
#
# n
# e
# w
#
# t
# e
# x
# t
# !
#
#
# A
# n
# d
#
# s
# o
# m
# e
#
# m
# o
# r
# e
#
# t
# e
# x
# t
# !
#
#
# Y
# e
# t
#
# e
# v
# e
# n
#
# m
# o
# r
# e
#
# t
# e
# x
# t
# !

# %%
with open("/content/practice3.txt", "r") as read_file:
    for line in read_file.readline():
      print(line)
# Out:
# F
# i
# r
# s
# t
#
# s
# e
# n
# t
# e
# n
# c
# e
# S
# e
# c
# o
# n
# d
#
# s
# e
# n
# t
# e
# n
# c
# e

# %%
with open("/content/practice3.txt", "r") as read_file:
    for line in read_file.readlines():
      print(line)
# Out:
# First sentenceSecond sentence
#
# Second sentenceHow many boards
#
# Could the Mongols hoard
#
# If the Mongols hordes got bored?Some new text!
#
# Some new text!
#
# And some more text!
#
# Yet even more text!

# %% [markdown]
# When Python reaches the end of a file with readlines, it will not start back at the beginning until you close the file and then reopen it.

# %% [markdown]
# **Change the print statement to print(line.upper())?**

# %%
with open("/content/practice3.txt", "r") as read_file:
    for line in read_file.readlines():
      print(line.upper())
# Out:
# FIRST SENTENCESECOND SENTENCE
#
# SECOND SENTENCEHOW MANY BOARDS
#
# COULD THE MONGOLS HOARD
#
# IF THE MONGOLS HORDES GOT BORED?SOME NEW TEXT!
#
# SOME NEW TEXT!
#
# AND SOME MORE TEXT!
#
# YET EVEN MORE TEXT!

# %% [markdown]
# **Change the print statement to print(line.replace("a", "\U0001F61C")))?**

# %%
with open("/content/practice3.txt", "r") as read_file:
    for line in read_file.readlines():
      print(line.replace("a", "\U0001F61C"))
# Out:
# First sentenceSecond sentence
#
# Second sentenceHow m😜ny bo😜rds
#
# Could the Mongols ho😜rd
#
# If the Mongols hordes got bored?Some new text!
#
# Some new text!
#
# And some more text!
#
# Yet even more text!

# %% [markdown]
#  * If you open the original text file, there are no empty lines. The original text has a newline character at the end of each line.
#  * The print command also adds a newline character by default. So Python prints two new lines: the first one goes to the next line, the second one creates the blank line.
#  * Use end="" in the print statement to remove the blank line. This replaces the newline character with an empty string.

# %%
with open("/content/practice3.txt", "r") as read_file:
    for line in read_file.readlines():
      print(line, end="")
# Out:
# First sentenceSecond sentence
# Second sentenceHow many boards
# Could the Mongols hoard
# If the Mongols hordes got bored?Some new text!
# Some new text!
# And some more text!
# Yet even more text!

# %% [markdown]
# **Change the print statement to print(line, end="!")?**

# %%
with open("/content/practice3.txt", "r") as read_file:
    for line in read_file.readlines():
      print(line, end="!")
# Out:
# First sentenceSecond sentence
# !Second sentenceHow many boards
# !Could the Mongols hoard
# !If the Mongols hordes got bored?Some new text!
# !Some new text!
# !And some more text!
# !Yet even more text!!

# %% [markdown]
# **Change the print statement to print(line, end="\n\n\n")?**

# %%
with open("/content/practice3.txt", "r") as read_file:
    for line in read_file.readlines():
      print(line, end="\n\n\n")
# Out:
# First sentenceSecond sentence
#
#
#
# Second sentenceHow many boards
#
#
#
# Could the Mongols hoard
#
#
#
# If the Mongols hordes got bored?Some new text!
#
#
#
# Some new text!
#
#
#
# And some more text!
#
#
#
# Yet even more text!

# %% [markdown]
# #### Readline vs. Readlines
# * The **readlines method** reads all of the lines at once and returns them in a list.
# * The **readline method** returns only one line from the text file.
# * Python automatically keeps track of which lines have been read, and which have not.

# %%
with open("/content/practice3.txt", "r") as read_file:
    print(read_file.readline())
# Out:
# First sentenceSecond sentence

# %% [markdown]
# **Change readline() to readlines()?**

# %%
with open("/content/practice3.txt", "r") as read_file:
    print(read_file.readlines())
# Out:
# ['First sentenceSecond sentence\n', 'Second sentenceHow many boards\n', 'Could the Mongols hoard\n', 'If the Mongols hordes got bored?Some new text!\n', 'Some new text!\n', 'And some more text!\n', 'Yet even more text!']

# %%
with open("/content/practice3.txt", "r") as read_file:
    print(read_file.readline(), end="")
    print(read_file.readline(), end="")
# Out:
# First sentenceSecond sentence
# Second sentenceHow many boards

# %% [markdown]
# #### While Loop
# * While loops can also iterate over a text file. But, while loops require a stop condition to keep it from becoming an infinite loop. Each text file ends with an empty string (""). That is how Python knows it has reached the end of a file.
# * So a while loop should iterate each line of the text file until it reaches the empty string. Because of this, iterating over a text with a while loop will use readline instead of readlines.
# * It is important to read the first line of the text file before starting the while loop. And, read the next line of the text file inside the while loop as well.

# %%
with open("/content/practice3.txt", "r") as read_file:
    line = read_file.readline()
    while line != "":
        print(line)
        line = read_file.readline()
# Out:
# First sentenceSecond sentence
#
# Second sentenceHow many boards
#
# Could the Mongols hoard
#
# If the Mongols hordes got bored?Some new text!
#
# Some new text!
#
# And some more text!
#
# Yet even more text!

# %% [markdown]
# **Change the first line = read_file.readline() to readlines()**

# %%
with open("/content/practice3.txt", "r") as read_file:
    line = read_file.readlines()
    while line != "":
        print(line)
        line = read_file.readline()
# Out:
# ['First sentenceSecond sentence\n', 'Second sentenceHow many boards\n', 'Could the Mongols hoard\n', 'If the Mongols hordes got bored?Some new text!\n', 'Some new text!\n', 'And some more text!\n', 'Yet even more text!']

# %% [markdown]
# **Remove the first line = read_file.readline()?**

# %%
with open("/content/practice3.txt", "r") as read_file:
    while line != "":
        print(line)
        line = read_file.readline()

# %% [markdown]
# **Put back the first line = read_file.readline() and remove the second one?**

# %%
# INFINITE LOOP
with open("/content/practice3.txt", "r") as read_file:
    line = read_file.readlines()
    while line != "":
        print(line)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['First sentenceSecond sentence\n', 'Second sentenceHow many boards\n', 'Could the Mongols hoard\n', 'If the Mongols hordes got bored?Some new text!\n', 'Some new text!\n', 'And some more text!\n', 'Yet even more text!']
# ['First sentenceSecond sentence\n', 'Second sentenceHow many boards\n', 'Could the Mongols hoard\n', 'If the Mongols hordes got bored?Some new text!\n', 'Some new text!\n', 'And some more text!\n', 'Yet even more text!']
# ['First sentenceSecond sentence\n', 'Second sentenceHow many boards\n', 'Could the Mongols hoard\n', 'If the Mongols hordes got bored?Some new text!\n', 'Some new text!\n', 'And some more text!\n', 'Yet even more text!']
# ['First sentenceSecond sentence\n', 'Second sentenceHow many boards\n', 'Could the Mongols hoard\n', 'If the Mongols hordes got bored?Some new text!\n', 'Some new text!\n', 'And some more text!\n', 'Yet even more text!']
# ...

# %% [markdown]
# * The readlines method reads all of the text file and returns all of the strings in a list.
#
# * The readline method reads one string at a time.

# %% [markdown]
# #### Seek Method
#
# * The seek method takes an integer as a parameter, and causes Python to go to a specific character in the text file.
# * The integer is the index for the text file. So seek(0) is the first character of the file, seek(1) is the second character, etc.

# %%
with open("/content/practice3.txt", "r") as read_file:
    read_file.seek(15)
    print(read_file.readline())
    read_file.seek(0)
    print(read_file.readline())

# %% [markdown]
# **Change a seek to 50?**

# %%
with open("/content/practice3.txt", "r") as read_file:
    read_file.seek(50)
    print(read_file.readline())
    read_file.seek(0)
    print(read_file.readline())

# %% [markdown]
# **Change a seek to 1000?**

# %%
with open("/content/practice3.txt", "r") as read_file:
    read_file.seek(1000)
    print(read_file.readline())
    read_file.seek(0)
    print(read_file.readline())

# %% [markdown]
# **Change a seek to -1?**

# %%
with open("/content/practice3.txt", "r") as read_file:
    read_file.seek(-1)
    print(read_file.readline())
    read_file.seek(0)
    print(read_file.readline())

# %% [markdown]
# #### Read a File Multiple Times
#
# * It was previously stated that a file cannot be read multiple times. That is true when trying to use readlines twice. You must close and then open the file to read it again.
# * However, the seek method can also be used to move Python back to the beginning of the text file.

# %%
with open("/content/practice3.txt", "r") as read_file:
    print("First Time")
    for line in read_file.readlines():
        print(line, end="")
    read_file.seek(0)
    print("\n\nSecond Time")
    for line in read_file.readlines():
        print(line, end="")

# %% [markdown]
# #### Read from One File and Write to Another
# * It is possible to open a file in read mode and another in write mode. Information can be passed from the reading file to the writing file.

# %%
with open("/content/practice3.txt", "r") as source, open("/content/destination.txt", "w") as dest:
    for line in source.readlines():
        dest.write(line)

# %%
with open("/content/destination.txt", "w") as dest, open("/content/practice3.txt", "r") as source:
  for line in source.readlines():
    dest.write(line.upper())

# %%
with open("/content/practice3.txt", "r") as source, open("/content/destination.txt", "w") as dest:
  for line in source.readlines():
      line += "\n"
      dest.write(line)
